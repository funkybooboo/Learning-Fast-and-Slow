# %% [markdown]
# <a href="https://colab.research.google.com/github/funkybooboo/Learning-Fast-and-Slow/blob/main/Fast%26Slow.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q --upgrade stable-baselines3>=2.0
# !pip install -q --upgrade sb3-contrib>=2.0
# !pip install -q --upgrade gymnasium
# Out:
# Requirement already satisfied: gymnasium in /usr/local/lib/python3.12/dist-packages (1.2.3)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium) (2.0.2)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium) (3.1.2)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium) (4.15.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.12/dist-packages (from gymnasium) (0.0.4)

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from collections import defaultdict
from queue import PriorityQueue
import threading
from threading import Thread

import stable_baselines3 as sb3
from stable_baselines3 import PPO, A2C, DQN, HerReplayBuffer
from sb3_contrib import ARS, TRPO, QRDQN
import torch

import gymnasium as gym
import numpy as np
from gymnasium import spaces

print(tf.__version__)
# Out:
# 2.19.0

# %% [markdown]
# # Define some sample next states and actions to try to learn by supervised learning

# %%
def getnextaction(state):
  cur_x, cur_y, goal_x, goal_y = state
  if cur_x > goal_x:
    return 0
  elif cur_x < goal_x:
    return 1
  elif cur_y > goal_y:
    return 2
  elif cur_y < goal_y:
    return 3
  else:
    return 4

# %%
# this is used for the alternate formulation
def getnextaction2(state):
  cur_x, cur_y, goal_x, goal_y = state
  if cur_y > goal_y:
    return 0
  elif cur_y < goal_y:
    return 1
  elif cur_x > goal_x:
    return 2
  elif cur_x < goal_x:
    return 3
  else:
    return 4

# %%
def getnextstate(state):
  cur_x, cur_y, goal_x, goal_y = state
  if cur_x > goal_x:
    return (cur_x-1, cur_y)
  elif cur_x < goal_x:
    return (cur_x+1, cur_y)
  elif cur_y > goal_y:
    return (cur_x, cur_y - 1)
  elif cur_y < goal_y:
    return (cur_x, cur_y+1)
  else:
    return (cur_x, cur_y)

# %%
# this is used for the alternate formulation
def getnextstate2(state):
  cur_x, cur_y, goal_x, goal_y = state
  if cur_y > goal_y:
    return (cur_x, cur_y - 1)
  elif cur_y < goal_y:
    return (cur_x, cur_y+1)
  elif cur_x > goal_x:
    return (cur_x-1, cur_y)
  elif cur_x < goal_x:
    return (cur_x+1, cur_y)
  else:
    return (cur_x, cur_y)

# %%
def GetSamples(grid_size = 10, seed = 0):
  np.random.seed(seed)
  states = np.random.randint(0, grid_size, (1000, 4))
  actions = np.array([getnextaction(state) for state in states])
  next_states = np.array([getnextstate(state) for state in states])

  actions2 = np.array([getnextaction2(state) for state in states])
  next_states2 = np.array([getnextstate2(state) for state in states])

  return states, actions, next_states, actions2, next_states2

# %% [markdown]
# # Experiment 1:
# # Input: Current State, Goal State
# # Output: Action
#
# This shows that learning an action given the current state and conditioned on the goal state is easy.

# %%
grid_size = 10
inputs = tf.keras.layers.Input(shape = (4,))
# x = tf.keras.layers.Conv2D(filters=16, kernel_size=(3,3), strides=(1,1), padding='same', activation = tf.nn.relu)(inputs)
# x = tf.keras.layers.MaxPooling2D(pool_size = (2,2))(x)
# x = tf.keras.layers.Flatten()(x)
x = tf.keras.layers.Dense(128, activation = tf.nn.relu)(inputs)
x = tf.keras.layers.Dense(128, activation = tf.nn.relu)(x)
output1 = tf.keras.layers.Dense(5, activation = tf.nn.softmax)(x)

model = tf.keras.Model(inputs = inputs, outputs = output1)

model.compile(optimizer = 'adam',
              loss = 'sparse_categorical_crossentropy', metrics = ['accuracy'])

states, actions, next_states, actions2, next_states2 = GetSamples(grid_size = 10)

datasize = len(states)
split = datasize//5 * 4
# reshape the input to add a channel dimension at the end for CNN processing
history = model.fit(states[:split], actions[:split], epochs=50)

## swap x and y priority for the next state
datasize = len(states)
split = datasize//5 * 4
# reshape the input to add a channel dimension at the end for CNN processing
history2 = model.fit(states[:split], actions2[:split], epochs=50)

action10 = history.history['accuracy']+history2.history['accuracy']
# Out:
# Epoch 1/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7738 - loss: 0.8046
# Epoch 2/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9050 - loss: 0.3936
# Epoch 3/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9212 - loss: 0.2607
# Epoch 4/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9563 - loss: 0.1908
# Epoch 5/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9750 - loss: 0.1512
# Epoch 6/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9837 - loss: 0.1225
# Epoch 7/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9837 - loss: 0.1033
# Epoch 8/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9900 - loss: 0.0892
# Epoch 9/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9887 - loss: 0.0772
# Epoch 10/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9925 - loss: 0.0633
# Epoch 11/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9950 - loss: 0.0557
# Epoch 12/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9937 - loss: 0.0467
# Epoch 13/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9950 - loss: 0.0419
# Epoch 14/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9950 - loss: 0.0378
# Epoch 15/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9950 - loss: 0.0361
# Epoch 16/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9962 - loss: 0.0308
# Epoch 17/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9975 - loss: 0.0272
# Epoch 18/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9950 - loss: 0.0263
# Epoch 19/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9950 - loss: 0.0255
# Epoch 20/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9987 - loss: 0.0213
# Epoch 21/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9950 - loss: 0.0210
# Epoch 22/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9962 - loss: 0.0185
# Epoch 23/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9962 - loss: 0.0179
# Epoch 24/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9962 - loss: 0.0172
# Epoch 25/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9962 - loss: 0.0152
# Epoch 26/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9975 - loss: 0.0143
# Epoch 27/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9987 - loss: 0.0151
# Epoch 28/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9987 - loss: 0.0130
# Epoch 29/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9987 - loss: 0.0117
# Epoch 30/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0117
# Epoch 31/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0116
# Epoch 32/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9975 - loss: 0.0117
# Epoch 33/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9937 - loss: 0.0169
# Epoch 34/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9937 - loss: 0.0214
# Epoch 35/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9912 - loss: 0.0201
# Epoch 36/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9987 - loss: 0.0108
# Epoch 37/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0088
# Epoch 38/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0084
# Epoch 39/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9987 - loss: 0.0083
# Epoch 40/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0074
# Epoch 41/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9975 - loss: 0.0085
# Epoch 42/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9987 - loss: 0.0076
# Epoch 43/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9975 - loss: 0.0097
# Epoch 44/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9962 - loss: 0.0091
# Epoch 45/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9987 - loss: 0.0068
# Epoch 46/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9987 - loss: 0.0064
# Epoch 47/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0058
# Epoch 48/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0053
# Epoch 49/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0051
# Epoch 50/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0048
# Epoch 1/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6137 - loss: 7.2664
# Epoch 2/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8913 - loss: 0.3305
# Epoch 3/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9250 - loss: 0.2136
# Epoch 4/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9675 - loss: 0.1652
# Epoch 5/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9812 - loss: 0.1363
# Epoch 6/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9837 - loss: 0.1159
# Epoch 7/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9812 - loss: 0.1081
# Epoch 8/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9925 - loss: 0.0891
# Epoch 9/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9887 - loss: 0.0808
# Epoch 10/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9925 - loss: 0.0700
# Epoch 11/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9937 - loss: 0.0637
# Epoch 12/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9937 - loss: 0.0580
# Epoch 13/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9937 - loss: 0.0530
# Epoch 14/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9937 - loss: 0.0487
# Epoch 15/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9937 - loss: 0.0460
# Epoch 16/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9925 - loss: 0.0433
# Epoch 17/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9925 - loss: 0.0418
# Epoch 18/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9950 - loss: 0.0386
# Epoch 19/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9937 - loss: 0.0365
# Epoch 20/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9950 - loss: 0.0338
# Epoch 21/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9962 - loss: 0.0326
# Epoch 22/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9962 - loss: 0.0310
# Epoch 23/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9962 - loss: 0.0288
# Epoch 24/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9962 - loss: 0.0282
# Epoch 25/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9975 - loss: 0.0273
# Epoch 26/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9975 - loss: 0.0254
# Epoch 27/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9987 - loss: 0.0240
# Epoch 28/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9975 - loss: 0.0231
# Epoch 29/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9975 - loss: 0.0230
# Epoch 30/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9962 - loss: 0.0212
# Epoch 31/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9975 - loss: 0.0199
# Epoch 32/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9987 - loss: 0.0196
# Epoch 33/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9975 - loss: 0.0184
# Epoch 34/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9975 - loss: 0.0181
# Epoch 35/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9987 - loss: 0.0174
# Epoch 36/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9987 - loss: 0.0164
# Epoch 37/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9987 - loss: 0.0162
# Epoch 38/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9987 - loss: 0.0152
# Epoch 39/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9987 - loss: 0.0145
# Epoch 40/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9987 - loss: 0.0148
# Epoch 41/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9975 - loss: 0.0145
# Epoch 42/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9987 - loss: 0.0133
# Epoch 43/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9987 - loss: 0.0130
# Epoch 44/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9987 - loss: 0.0123
# Epoch 45/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9987 - loss: 0.0122
# Epoch 46/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9987 - loss: 0.0120
# Epoch 47/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9987 - loss: 0.0113
# Epoch 48/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9975 - loss: 0.0120
# Epoch 49/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0114
# Epoch 50/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9975 - loss: 0.0114

# %%
grid_size = 20
inputs = tf.keras.layers.Input(shape = (4,))
# x = tf.keras.layers.Conv2D(filters=16, kernel_size=(3,3), strides=(1,1), padding='same', activation = tf.nn.relu)(inputs)
# x = tf.keras.layers.MaxPooling2D(pool_size = (2,2))(x)
# x = tf.keras.layers.Flatten()(x)
x = tf.keras.layers.Dense(128, activation = tf.nn.relu)(inputs)
x = tf.keras.layers.Dense(128, activation = tf.nn.relu)(x)
output1 = tf.keras.layers.Dense(5, activation = tf.nn.softmax)(x)

model = tf.keras.Model(inputs = inputs, outputs = output1)

model.compile(optimizer = 'adam',
              loss = 'sparse_categorical_crossentropy', metrics = ['accuracy'])

states, actions, next_states, actions2, next_states2 = GetSamples(grid_size = 20)

datasize = len(states)
split = datasize//5 * 4
history = model.fit(states[:split], actions[:split], epochs=50)

## swap x and y priority for the next state
datasize = len(states)
split = datasize//5 * 4
history2 = model.fit(states[:split], actions2[:split], epochs=50)

action20 = history.history['accuracy']+history2.history['accuracy']
# Out:
# Epoch 1/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.7688 - loss: 1.0466
# Epoch 2/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9488 - loss: 0.3160
# Epoch 3/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9625 - loss: 0.2025
# Epoch 4/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9638 - loss: 0.1591
# Epoch 5/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9625 - loss: 0.1332
# Epoch 6/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9712 - loss: 0.1134
# Epoch 7/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9750 - loss: 0.0993
# Epoch 8/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9663 - loss: 0.0935
# Epoch 9/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9675 - loss: 0.0951
# Epoch 10/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9650 - loss: 0.0904
# Epoch 11/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9837 - loss: 0.0705
# Epoch 12/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9850 - loss: 0.0619
# Epoch 13/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9800 - loss: 0.0635
# Epoch 14/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9850 - loss: 0.0571
# Epoch 15/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9912 - loss: 0.0515
# Epoch 16/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9850 - loss: 0.0516
# Epoch 17/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9812 - loss: 0.0533
# Epoch 18/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9812 - loss: 0.0511
# Epoch 19/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9850 - loss: 0.0514
# Epoch 20/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9812 - loss: 0.0501
# Epoch 21/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9900 - loss: 0.0442
# Epoch 22/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9937 - loss: 0.0372
# Epoch 23/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9950 - loss: 0.0359
# Epoch 24/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9912 - loss: 0.0363
# Epoch 25/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9950 - loss: 0.0317
# Epoch 26/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9975 - loss: 0.0287
# Epoch 27/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9950 - loss: 0.0337
# Epoch 28/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9925 - loss: 0.0335
# Epoch 29/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9975 - loss: 0.0263
# Epoch 30/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9987 - loss: 0.0263
# Epoch 31/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9975 - loss: 0.0262
# Epoch 32/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9925 - loss: 0.0250
# Epoch 33/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9987 - loss: 0.0219
# Epoch 34/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9987 - loss: 0.0191
# Epoch 35/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9987 - loss: 0.0183
# Epoch 36/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9987 - loss: 0.0185
# Epoch 37/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9975 - loss: 0.0198
# Epoch 38/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9925 - loss: 0.0253
# Epoch 39/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9975 - loss: 0.0177
# Epoch 40/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9987 - loss: 0.0143
# Epoch 41/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9987 - loss: 0.0143
# Epoch 42/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9987 - loss: 0.0147
# Epoch 43/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9987 - loss: 0.0145
# Epoch 44/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9975 - loss: 0.0141
# Epoch 45/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9987 - loss: 0.0153
# Epoch 46/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9975 - loss: 0.0138
# Epoch 47/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9987 - loss: 0.0139
# Epoch 48/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9975 - loss: 0.0119
# Epoch 49/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9987 - loss: 0.0125
# Epoch 50/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9987 - loss: 0.0107
# Epoch 1/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6800 - loss: 6.0442
# Epoch 2/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9187 - loss: 0.2865
# Epoch 3/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9438 - loss: 0.1934
# Epoch 4/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9588 - loss: 0.1421
# Epoch 5/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9700 - loss: 0.1179
# Epoch 6/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9613 - loss: 0.1087
# Epoch 7/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9750 - loss: 0.0925
# Epoch 8/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9675 - loss: 0.0985
# Epoch 9/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9712 - loss: 0.0872
# Epoch 10/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9775 - loss: 0.0796
# Epoch 11/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9887 - loss: 0.0656
# Epoch 12/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9925 - loss: 0.0647
# Epoch 13/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9900 - loss: 0.0585
# Epoch 14/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9925 - loss: 0.0550
# Epoch 15/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9862 - loss: 0.0623
# Epoch 16/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9887 - loss: 0.0556
# Epoch 17/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9812 - loss: 0.0576
# Epoch 18/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9837 - loss: 0.0565
# Epoch 19/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9887 - loss: 0.0463
# Epoch 20/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9962 - loss: 0.0416
# Epoch 21/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9975 - loss: 0.0363
# Epoch 22/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9975 - loss: 0.0355
# Epoch 23/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9975 - loss: 0.0337
# Epoch 24/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9975 - loss: 0.0314
# Epoch 25/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9987 - loss: 0.0307
# Epoch 26/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9975 - loss: 0.0322
# Epoch 27/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9987 - loss: 0.0282
# Epoch 28/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9987 - loss: 0.0257
# Epoch 29/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9987 - loss: 0.0254
# Epoch 30/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9975 - loss: 0.0250
# Epoch 31/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9925 - loss: 0.0326
# Epoch 32/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9975 - loss: 0.0249
# Epoch 33/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9987 - loss: 0.0217
# Epoch 34/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9975 - loss: 0.0218
# Epoch 35/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9987 - loss: 0.0192
# Epoch 36/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9975 - loss: 0.0185
# Epoch 37/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9987 - loss: 0.0170
# Epoch 38/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9987 - loss: 0.0174
# Epoch 39/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9987 - loss: 0.0162
# Epoch 40/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9987 - loss: 0.0168
# Epoch 41/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9987 - loss: 0.0149
# Epoch 42/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9975 - loss: 0.0160
# Epoch 43/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9975 - loss: 0.0165
# Epoch 44/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0147
# Epoch 45/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0131
# Epoch 46/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9987 - loss: 0.0143
# Epoch 47/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0127
# Epoch 48/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0113
# Epoch 49/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9987 - loss: 0.0110
# Epoch 50/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9987 - loss: 0.0108

# %%
plt.plot(action10, 'b', label = 'Next Action Prediction 10x10')
plt.plot(action20, 'r', label = 'Next Action Prediction 20x20')
plt.xlabel('Number of Epochs')
plt.ylabel('Accuracy')
plt.xticks([i*10 for i in range(11)])
plt.grid()
plt.legend(loc = 'lower right')

# %% [markdown]
# # Experiment 2
# # Input: Current State, Goal State
# # Output: Next State
#
# This shows that learning the next state conditioned on current state and goal state is difficult.

# %%
grid_size = 10
inputs = tf.keras.layers.Input(shape = (4,))
# x = tf.keras.layers.Conv2D(filters=16, kernel_size=(3,3), strides=(1,1), padding='same', activation = tf.nn.relu)(inputs)
# x = tf.keras.layers.MaxPooling2D(pool_size = (2,2))(x)
# x = tf.keras.layers.Flatten()(x)
x = tf.keras.layers.Dense(128, activation = tf.nn.relu)(inputs)
x = tf.keras.layers.Dense(128, activation = tf.nn.relu)(x)
output1 = tf.keras.layers.Dense(grid_size, activation = tf.nn.softmax, name = 'state_x')(x)
output2 = tf.keras.layers.Dense(grid_size, activation = tf.nn.softmax, name = 'state_y')(x)

model2 = tf.keras.Model(inputs = inputs, outputs = [output1, output2])

model2.compile(optimizer = 'adam',
              loss = 'sparse_categorical_crossentropy', metrics = ['accuracy', 'accuracy'])

states, actions, next_states, actions2, next_states2 = GetSamples(grid_size = 10)

datasize = len(states)
split = datasize//5 * 4
history = model2.fit(states[:split], [next_states[:split][:,0], next_states[:split][:,1]], epochs=200)

## swap x and y priority for next state
datasize = len(states)
split = datasize//5 * 4
history2 = model2.fit(states[:split], [next_states2[:split][:,0], next_states2[:split][:,1]], epochs=200)

acc_x = history.history['state_x_accuracy']+history2.history['state_x_accuracy']
acc_y = history.history['state_y_accuracy']+history2.history['state_y_accuracy']
nextstate10 = (np.array(acc_x)+np.array(acc_y))/2
# Out:
# Epoch 1/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step
# Epoch 84/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2211 - state_x_accuracy: 0.9400 - state_x_loss: 0.1558 - state_y_accuracy: 0.9912 - state_y_loss: 0.0653
# Epoch 85/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2043 - state_x_accuracy: 0.9538 - state_x_loss: 0.1451 - state_y_accuracy: 0.9950 - state_y_loss: 0.0592
# Epoch 86/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2248 - state_x_accuracy: 0.9375 - state_x_loss: 0.1640 - state_y_accuracy: 0.9925 - state_y_loss: 0.0609
# Epoch 87/200
# ...
# Epoch 106/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1784 - state_x_accuracy: 0.9488 - state_x_loss: 0.1304 - state_y_accuracy: 0.9937 - state_y_loss: 0.0480
# Epoch 107/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1644 - state_x_accuracy: 0.9538 - state_x_loss: 0.1248 - state_y_accuracy: 0.9987 - state_y_loss: 0.0396
# Epoch 108/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1557 - state_x_accuracy: 0.9588 - state_x_loss: 0.1119 - state_y_accuracy: 0.9962 - state_y_loss: 0.0438
# Epoch 109/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1606 - state_x_accuracy: 0.9600 - state_x_loss: 0.1108 - state_y_accuracy: 0.9950 - state_y_loss: 0.0498
# Epoch 110/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1505 - state_x_accuracy: 0.9638 - state_x_loss: 0.1110 - state_y_accuracy: 0.9975 - state_y_loss: 0.0394
# Epoch 111/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1544 - state_x_accuracy: 0.9600 - state_x_loss: 0.1133 - state_y_accuracy: 0.9962 - state_y_loss: 0.0411
# Epoch 112/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1626 - state_x_accuracy: 0.9525 - state_x_loss: 0.1248 - state_y_accuracy: 0.9975 - state_y_loss: 0.0378
# Epoch 113/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1337 - state_x_accuracy: 0.9675 - state_x_loss: 0.0995 - state_y_accuracy: 1.0000 - state_y_loss: 0.0342
# Epoch 114/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1505 - state_x_accuracy: 0.9650 - state_x_loss: 0.1139 - state_y_accuracy: 0.9975 - state_y_loss: 0.0367
# Epoch 115/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1353 - state_x_accuracy: 0.9700 - state_x_loss: 0.0997 - state_y_accuracy: 0.9987 - state_y_loss: 0.0356
# Epoch 116/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1395 - state_x_accuracy: 0.9675 - state_x_loss: 0.1084 - state_y_accuracy: 1.0000 - state_y_loss: 0.0312
# Epoch 117/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1452 - state_x_accuracy: 0.9550 - state_x_loss: 0.1112 - state_y_accuracy: 1.0000 - state_y_loss: 0.0341
# Epoch 118/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1396 - state_x_accuracy: 0.9600 - state_x_loss: 0.1062 - state_y_accuracy: 0.9975 - state_y_loss: 0.0334
# Epoch 119/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1339 - state_x_accuracy: 0.9688 - state_x_loss: 0.0956 - state_y_accuracy: 0.9962 - state_y_loss: 0.0384
# Epoch 120/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1307 - state_x_accuracy: 0.9688 - state_x_loss: 0.0977 - state_y_accuracy: 1.0000 - state_y_loss: 0.0330
# Epoch 121/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1263 - state_x_accuracy: 0.9663 - state_x_loss: 0.0960 - state_y_accuracy: 1.0000 - state_y_loss: 0.0304
# Epoch 122/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1244 - state_x_accuracy: 0.9787 - state_x_loss: 0.0944 - state_y_accuracy: 1.0000 - state_y_loss: 0.0300
# Epoch 123/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1184 - state_x_accuracy: 0.9737 - state_x_loss: 0.0892 - state_y_accuracy: 1.0000 - state_y_loss: 0.0292
# Epoch 124/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1113 - state_x_accuracy: 0.9750 - state_x_loss: 0.0834 - state_y_accuracy: 1.0000 - state_y_loss: 0.0279
# Epoch 125/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1244 - state_x_accuracy: 0.9700 - state_x_loss: 0.0929 - state_y_accuracy: 1.0000 - state_y_loss: 0.0315
# Epoch 126/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1145 - state_x_accuracy: 0.9750 - state_x_loss: 0.0847 - state_y_accuracy: 1.0000 - state_y_loss: 0.0297
# Epoch 127/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1450 - state_x_accuracy: 0.9638 - state_x_loss: 0.1143 - state_y_accuracy: 1.0000 - state_y_loss: 0.0308
# Epoch 128/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1358 - state_x_accuracy: 0.9688 - state_x_loss: 0.0987 - state_y_accuracy: 0.9962 - state_y_loss: 0.0371
# Epoch 129/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1160 - state_x_accuracy: 0.9688 - state_x_loss: 0.0895 - state_y_accuracy: 1.0000 - state_y_loss: 0.0265
# Epoch 130/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1148 - state_x_accuracy: 0.9725 - state_x_loss: 0.0894 - state_y_accuracy: 1.0000 - state_y_loss: 0.0254
# Epoch 131/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1161 - state_x_accuracy: 0.9700 - state_x_loss: 0.0907 - state_y_accuracy: 1.0000 - state_y_loss: 0.0253
# Epoch 132/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1153 - state_x_accuracy: 0.9675 - state_x_loss: 0.0911 - state_y_accuracy: 1.0000 - state_y_loss: 0.0241
# Epoch 133/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1021 - state_x_accuracy: 0.9762 - state_x_loss: 0.0772 - state_y_accuracy: 1.0000 - state_y_loss: 0.0248
# Epoch 134/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1026 - state_x_accuracy: 0.9775 - state_x_loss: 0.0771 - state_y_accuracy: 0.9987 - state_y_loss: 0.0255
# Epoch 135/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1020 - state_x_accuracy: 0.9775 - state_x_loss: 0.0793 - state_y_accuracy: 1.0000 - state_y_loss: 0.0227
# Epoch 136/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1136 - state_x_accuracy: 0.9712 - state_x_loss: 0.0893 - state_y_accuracy: 1.0000 - state_y_loss: 0.0242
# Epoch 137/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1193 - state_x_accuracy: 0.9750 - state_x_loss: 0.0916 - state_y_accuracy: 1.0000 - state_y_loss: 0.0277
# Epoch 138/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0986 - state_x_accuracy: 0.9762 - state_x_loss: 0.0753 - state_y_accuracy: 1.0000 - state_y_loss: 0.0233
# Epoch 139/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1132 - state_x_accuracy: 0.9762 - state_x_loss: 0.0867 - state_y_accuracy: 0.9987 - state_y_loss: 0.0266
# Epoch 140/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1053 - state_x_accuracy: 0.9775 - state_x_loss: 0.0822 - state_y_accuracy: 1.0000 - state_y_loss: 0.0230
# Epoch 141/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1170 - state_x_accuracy: 0.9737 - state_x_loss: 0.0905 - state_y_accuracy: 0.9975 - state_y_loss: 0.0265
# Epoch 142/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1071 - state_x_accuracy: 0.9737 - state_x_loss: 0.0843 - state_y_accuracy: 0.9987 - state_y_loss: 0.0228
# Epoch 143/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0962 - state_x_accuracy: 0.9800 - state_x_loss: 0.0745 - state_y_accuracy: 1.0000 - state_y_loss: 0.0218
# Epoch 144/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0983 - state_x_accuracy: 0.9762 - state_x_loss: 0.0770 - state_y_accuracy: 1.0000 - state_y_loss: 0.0213
# Epoch 145/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0949 - state_x_accuracy: 0.9787 - state_x_loss: 0.0757 - state_y_accuracy: 1.0000 - state_y_loss: 0.0191
# Epoch 146/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1096 - state_x_accuracy: 0.9737 - state_x_loss: 0.0878 - state_y_accuracy: 1.0000 - state_y_loss: 0.0218
# Epoch 147/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0995 - state_x_accuracy: 0.9775 - state_x_loss: 0.0787 - state_y_accuracy: 1.0000 - state_y_loss: 0.0208
# Epoch 148/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0969 - state_x_accuracy: 0.9812 - state_x_loss: 0.0749 - state_y_accuracy: 0.9987 - state_y_loss: 0.0220
# Epoch 149/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0982 - state_x_accuracy: 0.9775 - state_x_loss: 0.0759 - state_y_accuracy: 0.9975 - state_y_loss: 0.0223
# Epoch 150/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0895 - state_x_accuracy: 0.9812 - state_x_loss: 0.0683 - state_y_accuracy: 0.9987 - state_y_loss: 0.0212
# Epoch 151/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1018 - state_x_accuracy: 0.9737 - state_x_loss: 0.0788 - state_y_accuracy: 0.9987 - state_y_loss: 0.0229
# Epoch 152/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1079 - state_x_accuracy: 0.9700 - state_x_loss: 0.0886 - state_y_accuracy: 1.0000 - state_y_loss: 0.0192
# Epoch 153/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0949 - state_x_accuracy: 0.9800 - state_x_loss: 0.0736 - state_y_accuracy: 0.9987 - state_y_loss: 0.0213
# Epoch 154/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0922 - state_x_accuracy: 0.9762 - state_x_loss: 0.0719 - state_y_accuracy: 0.9987 - state_y_loss: 0.0203
# Epoch 155/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0918 - state_x_accuracy: 0.9775 - state_x_loss: 0.0747 - state_y_accuracy: 1.0000 - state_y_loss: 0.0171
# Epoch 156/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0792 - state_x_accuracy: 0.9825 - state_x_loss: 0.0629 - state_y_accuracy: 1.0000 - state_y_loss: 0.0162
# Epoch 157/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0840 - state_x_accuracy: 0.9812 - state_x_loss: 0.0664 - state_y_accuracy: 1.0000 - state_y_loss: 0.0176
# Epoch 158/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0866 - state_x_accuracy: 0.9775 - state_x_loss: 0.0689 - state_y_accuracy: 1.0000 - state_y_loss: 0.0177
# Epoch 159/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0813 - state_x_accuracy: 0.9800 - state_x_loss: 0.0665 - state_y_accuracy: 1.0000 - state_y_loss: 0.0147
# Epoch 160/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0774 - state_x_accuracy: 0.9887 - state_x_loss: 0.0609 - state_y_accuracy: 1.0000 - state_y_loss: 0.0165
# Epoch 161/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0840 - state_x_accuracy: 0.9862 - state_x_loss: 0.0646 - state_y_accuracy: 1.0000 - state_y_loss: 0.0194
# Epoch 162/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0864 - state_x_accuracy: 0.9800 - state_x_loss: 0.0693 - state_y_accuracy: 1.0000 - state_y_loss: 0.0171
# Epoch 163/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0823 - state_x_accuracy: 0.9825 - state_x_loss: 0.0668 - state_y_accuracy: 1.0000 - state_y_loss: 0.0155
# Epoch 164/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0801 - state_x_accuracy: 0.9875 - state_x_loss: 0.0614 - state_y_accuracy: 1.0000 - state_y_loss: 0.0187
# Epoch 165/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0720 - state_x_accuracy: 0.9862 - state_x_loss: 0.0560 - state_y_accuracy: 1.0000 - state_y_loss: 0.0160
# Epoch 166/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0926 - state_x_accuracy: 0.9837 - state_x_loss: 0.0670 - state_y_accuracy: 0.9950 - state_y_loss: 0.0257
# Epoch 167/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0915 - state_x_accuracy: 0.9850 - state_x_loss: 0.0689 - state_y_accuracy: 0.9975 - state_y_loss: 0.0226
# Epoch 168/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0777 - state_x_accuracy: 0.9887 - state_x_loss: 0.0559 - state_y_accuracy: 0.9975 - state_y_loss: 0.0218
# Epoch 169/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0674 - state_x_accuracy: 0.9900 - state_x_loss: 0.0530 - state_y_accuracy: 1.0000 - state_y_loss: 0.0144
# Epoch 170/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0677 - state_x_accuracy: 0.9862 - state_x_loss: 0.0556 - state_y_accuracy: 1.0000 - state_y_loss: 0.0121
# Epoch 171/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0682 - state_x_accuracy: 0.9875 - state_x_loss: 0.0553 - state_y_accuracy: 1.0000 - state_y_loss: 0.0128
# Epoch 172/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0805 - state_x_accuracy: 0.9825 - state_x_loss: 0.0646 - state_y_accuracy: 1.0000 - state_y_loss: 0.0159
# Epoch 173/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0775 - state_x_accuracy: 0.9837 - state_x_loss: 0.0621 - state_y_accuracy: 1.0000 - state_y_loss: 0.0154
# Epoch 174/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0611 - state_x_accuracy: 0.9925 - state_x_loss: 0.0493 - state_y_accuracy: 1.0000 - state_y_loss: 0.0118
# Epoch 175/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0802 - state_x_accuracy: 0.9812 - state_x_loss: 0.0657 - state_y_accuracy: 1.0000 - state_y_loss: 0.0145
# Epoch 176/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0783 - state_x_accuracy: 0.9862 - state_x_loss: 0.0621 - state_y_accuracy: 1.0000 - state_y_loss: 0.0162
# Epoch 177/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0618 - state_x_accuracy: 0.9912 - state_x_loss: 0.0496 - state_y_accuracy: 1.0000 - state_y_loss: 0.0122
# Epoch 178/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0644 - state_x_accuracy: 0.9850 - state_x_loss: 0.0533 - state_y_accuracy: 1.0000 - state_y_loss: 0.0111
# Epoch 179/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0866 - state_x_accuracy: 0.9737 - state_x_loss: 0.0715 - state_y_accuracy: 0.9987 - state_y_loss: 0.0151
# Epoch 180/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0819 - state_x_accuracy: 0.9800 - state_x_loss: 0.0676 - state_y_accuracy: 0.9987 - state_y_loss: 0.0143
# Epoch 181/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0618 - state_x_accuracy: 0.9875 - state_x_loss: 0.0502 - state_y_accuracy: 1.0000 - state_y_loss: 0.0116
# Epoch 182/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0655 - state_x_accuracy: 0.9837 - state_x_loss: 0.0547 - state_y_accuracy: 1.0000 - state_y_loss: 0.0108
# Epoch 183/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0591 - state_x_accuracy: 0.9887 - state_x_loss: 0.0481 - state_y_accuracy: 1.0000 - state_y_loss: 0.0111
# Epoch 184/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0603 - state_x_accuracy: 0.9900 - state_x_loss: 0.0485 - state_y_accuracy: 1.0000 - state_y_loss: 0.0119
# Epoch 185/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0737 - state_x_accuracy: 0.9825 - state_x_loss: 0.0595 - state_y_accuracy: 0.9987 - state_y_loss: 0.0143
# Epoch 186/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0706 - state_x_accuracy: 0.9825 - state_x_loss: 0.0605 - state_y_accuracy: 1.0000 - state_y_loss: 0.0101
# Epoch 187/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0554 - state_x_accuracy: 0.9925 - state_x_loss: 0.0444 - state_y_accuracy: 1.0000 - state_y_loss: 0.0110
# Epoch 188/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0613 - state_x_accuracy: 0.9875 - state_x_loss: 0.0512 - state_y_accuracy: 1.0000 - state_y_loss: 0.0101
# Epoch 189/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0610 - state_x_accuracy: 0.9875 - state_x_loss: 0.0510 - state_y_accuracy: 1.0000 - state_y_loss: 0.0101
# Epoch 190/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0728 - state_x_accuracy: 0.9787 - state_x_loss: 0.0584 - state_y_accuracy: 0.9987 - state_y_loss: 0.0144
# Epoch 191/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0617 - state_x_accuracy: 0.9925 - state_x_loss: 0.0488 - state_y_accuracy: 0.9987 - state_y_loss: 0.0128
# Epoch 192/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0636 - state_x_accuracy: 0.9862 - state_x_loss: 0.0508 - state_y_accuracy: 1.0000 - state_y_loss: 0.0127
# Epoch 193/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0549 - state_x_accuracy: 0.9937 - state_x_loss: 0.0449 - state_y_accuracy: 1.0000 - state_y_loss: 0.0101
# Epoch 194/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0577 - state_x_accuracy: 0.9887 - state_x_loss: 0.0487 - state_y_accuracy: 1.0000 - state_y_loss: 0.0090
# Epoch 195/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0641 - state_x_accuracy: 0.9887 - state_x_loss: 0.0514 - state_y_accuracy: 1.0000 - state_y_loss: 0.0127
# Epoch 196/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0608 - state_x_accuracy: 0.9900 - state_x_loss: 0.0508 - state_y_accuracy: 1.0000 - state_y_loss: 0.0100
# Epoch 197/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0583 - state_x_accuracy: 0.9912 - state_x_loss: 0.0500 - state_y_accuracy: 1.0000 - state_y_loss: 0.0083
# Epoch 198/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0583 - state_x_accuracy: 0.9837 - state_x_loss: 0.0500 - state_y_accuracy: 1.0000 - state_y_loss: 0.0083
# Epoch 199/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0643 - state_x_accuracy: 0.9862 - state_x_loss: 0.0539 - state_y_accuracy: 1.0000 - state_y_loss: 0.0104
# Epoch 200/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0650 - state_x_accuracy: 0.9937 - state_x_loss: 0.0531 - state_y_accuracy: 0.9987 - state_y_loss: 0.0119

# %%
grid_size = 20
inputs = tf.keras.layers.Input(shape = (4,))
# x = tf.keras.layers.Conv2D(filters=16, kernel_size=(3,3), strides=(1,1), padding='same', activation = tf.nn.relu)(inputs)
# x = tf.keras.layers.MaxPooling2D(pool_size = (2,2))(x)
# x = tf.keras.layers.Flatten()(x)
x = tf.keras.layers.Dense(128, activation = tf.nn.relu)(inputs)
x = tf.keras.layers.Dense(128, activation = tf.nn.relu)(x)
output1 = tf.keras.layers.Dense(grid_size, activation = tf.nn.softmax, name = 'state_x')(x)
output2 = tf.keras.layers.Dense(grid_size, activation = tf.nn.softmax, name = 'state_y')(x)

model2 = tf.keras.Model(inputs = inputs, outputs = [output1, output2])

model2.compile(optimizer = 'adam',
              loss = 'sparse_categorical_crossentropy', metrics = ['accuracy', 'accuracy'])

states, actions, next_states, actions2, next_states2 = GetSamples(grid_size = 20)

datasize = len(states)
split = datasize//5 * 4
history = model2.fit(states[:split], [next_states[:split][:,0], next_states[:split][:,1]], epochs=200)

## swap x and y priority for next state
datasize = len(states)
split = datasize//5 * 4
history2 = model2.fit(states[:split], [next_states2[:split][:,0], next_states2[:split][:,1]], epochs=200)

acc_x = history.history['state_x_accuracy']+history2.history['state_x_accuracy']
acc_y = history.history['state_y_accuracy']+history2.history['state_y_accuracy']
nextstate20 = (np.array(acc_x)+np.array(acc_y))/2
# Out:
# Epoch 1/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 6.3044 - state_x_accuracy: 0.0938 - state_x_loss: 3.1392 - state_y_accuracy: 0.0600 - state_y_loss: 3.1652
# Epoch 2/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.1628 - state_x_accuracy: 0.1625 - state_x_loss: 2.5087 - state_y_accuracy: 0.1088 - state_y_loss: 2.6541
# Epoch 3/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.8264 - state_x_accuracy: 0.1963 - state_x_loss: 2.3214 - state_y_accuracy: 0.1562 - state_y_loss: 2.5051
# Epoch 4/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.6092 - state_x_accuracy: 0.2113 - state_x_loss: 2.2324 - state_y_accuracy: 0.1838 - state_y_loss: 2.3768
# Epoch 5/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.4496 - state_x_accuracy: 0.2200 - state_x_loss: 2.1619 - state_y_accuracy: 0.1963 - state_y_loss: 2.2877
# Epoch 6/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.3002 - state_x_accuracy: 0.2488 - state_x_loss: 2.0912 - state_y_accuracy: 0.2250 - state_y_loss: 2.2090
# Epoch 7/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.2148 - state_x_accuracy: 0.2637 - state_x_loss: 2.0464 - state_y_accuracy: 0.2300 - state_y_loss: 2.1685
# Epoch 8/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.1207 - state_x_accuracy: 0.2663 - state_x_loss: 2.0242 - state_y_accuracy: 0.2713 - state_y_loss: 2.0966
# Epoch 9/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.0538 - state_x_accuracy: 0.2850 - state_x_loss: 1.9920 - state_y_accuracy: 0.2500 - state_y_loss: 2.0618
# Epoch 10/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.9940 - state_x_accuracy: 0.2763 - state_x_loss: 1.9746 - state_y_accuracy: 0.2825 - state_y_loss: 2.0195
# Epoch 11/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.9063 - state_x_accuracy: 0.2950 - state_x_loss: 1.9300 - state_y_accuracy: 0.2962 - state_y_loss: 1.9763
# Epoch 12/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.8825 - state_x_accuracy: 0.2962 - state_x_loss: 1.9217 - state_y_accuracy: 0.2975 - state_y_loss: 1.9608
# Epoch 13/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.7836 - state_x_accuracy: 0.3237 - state_x_loss: 1.8728 - state_y_accuracy: 0.3225 - state_y_loss: 1.9108
# Epoch 14/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.7107 - state_x_accuracy: 0.3338 - state_x_loss: 1.8387 - state_y_accuracy: 0.3363 - state_y_loss: 1.8720
# Epoch 15/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6879 - state_x_accuracy: 0.3125 - state_x_loss: 1.8267 - state_y_accuracy: 0.3225 - state_y_loss: 1.8612
# Epoch 16/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6113 - state_x_accuracy: 0.3475 - state_x_loss: 1.7880 - state_y_accuracy: 0.3300 - state_y_loss: 1.8233
# Epoch 17/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.5809 - state_x_accuracy: 0.3500 - state_x_loss: 1.7765 - state_y_accuracy: 0.3487 - state_y_loss: 1.8044
# Epoch 18/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.5242 - state_x_accuracy: 0.3388 - state_x_loss: 1.7601 - state_y_accuracy: 0.3613 - state_y_loss: 1.7641
# Epoch 19/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.5136 - state_x_accuracy: 0.3625 - state_x_loss: 1.7482 - state_y_accuracy: 0.3738 - state_y_loss: 1.7654
# Epoch 20/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.4627 - state_x_accuracy: 0.3537 - state_x_loss: 1.7276 - state_y_accuracy: 0.3887 - state_y_loss: 1.7351
# Epoch 21/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.4531 - state_x_accuracy: 0.3562 - state_x_loss: 1.7382 - state_y_accuracy: 0.3812 - state_y_loss: 1.7149
# Epoch 22/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.4602 - state_x_accuracy: 0.3350 - state_x_loss: 1.7213 - state_y_accuracy: 0.3725 - state_y_loss: 1.7389
# Epoch 23/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.3803 - state_x_accuracy: 0.3625 - state_x_loss: 1.6802 - state_y_accuracy: 0.3438 - state_y_loss: 1.7001
# Epoch 24/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.3735 - state_x_accuracy: 0.3575 - state_x_loss: 1.6710 - state_y_accuracy: 0.3762 - state_y_loss: 1.7024
# Epoch 25/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.3253 - state_x_accuracy: 0.3925 - state_x_loss: 1.6611 - state_y_accuracy: 0.3887 - state_y_loss: 1.6642
# Epoch 26/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.2662 - state_x_accuracy: 0.3750 - state_x_loss: 1.6369 - state_y_accuracy: 0.3963 - state_y_loss: 1.6293
# Epoch 27/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.2704 - state_x_accuracy: 0.3925 - state_x_loss: 1.6578 - state_y_accuracy: 0.4175 - state_y_loss: 1.6126
# Epoch 28/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.1966 - state_x_accuracy: 0.4050 - state_x_loss: 1.6052 - state_y_accuracy: 0.4238 - state_y_loss: 1.5914
# Epoch 29/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.1792 - state_x_accuracy: 0.3925 - state_x_loss: 1.6024 - state_y_accuracy: 0.4325 - state_y_loss: 1.5768
# Epoch 30/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.1733 - state_x_accuracy: 0.4025 - state_x_loss: 1.5892 - state_y_accuracy: 0.4062 - state_y_loss: 1.5841
# Epoch 31/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.1397 - state_x_accuracy: 0.3963 - state_x_loss: 1.5864 - state_y_accuracy: 0.4225 - state_y_loss: 1.5533
# Epoch 32/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.1084 - state_x_accuracy: 0.4112 - state_x_loss: 1.5683 - state_y_accuracy: 0.4450 - state_y_loss: 1.5401
# Epoch 33/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.0557 - state_x_accuracy: 0.4325 - state_x_loss: 1.5445 - state_y_accuracy: 0.4500 - state_y_loss: 1.5112
# Epoch 34/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.0316 - state_x_accuracy: 0.4112 - state_x_loss: 1.5228 - state_y_accuracy: 0.4425 - state_y_loss: 1.5088
# Epoch 35/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.0302 - state_x_accuracy: 0.4238 - state_x_loss: 1.5179 - state_y_accuracy: 0.4338 - state_y_loss: 1.5122
# Epoch 36/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.9696 - state_x_accuracy: 0.4175 - state_x_loss: 1.5021 - state_y_accuracy: 0.4462 - state_y_loss: 1.4675
# Epoch 37/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.9524 - state_x_accuracy: 0.4200 - state_x_loss: 1.4875 - state_y_accuracy: 0.4688 - state_y_loss: 1.4649
# Epoch 38/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.9175 - state_x_accuracy: 0.4437 - state_x_loss: 1.4583 - state_y_accuracy: 0.4437 - state_y_loss: 1.4591
# Epoch 39/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.8989 - state_x_accuracy: 0.4525 - state_x_loss: 1.4742 - state_y_accuracy: 0.4837 - state_y_loss: 1.4246
# Epoch 40/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.8944 - state_x_accuracy: 0.4675 - state_x_loss: 1.4704 - state_y_accuracy: 0.4525 - state_y_loss: 1.4240
# Epoch 41/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.8158 - state_x_accuracy: 0.4812 - state_x_loss: 1.4051 - state_y_accuracy: 0.4688 - state_y_loss: 1.4108
# Epoch 42/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.7533 - state_x_accuracy: 0.4750 - state_x_loss: 1.3833 - state_y_accuracy: 0.4988 - state_y_loss: 1.3700
# Epoch 43/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.7279 - state_x_accuracy: 0.4700 - state_x_loss: 1.3736 - state_y_accuracy: 0.5225 - state_y_loss: 1.3543
# Epoch 44/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.7117 - state_x_accuracy: 0.4762 - state_x_loss: 1.3786 - state_y_accuracy: 0.5050 - state_y_loss: 1.3331
# Epoch 45/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.6832 - state_x_accuracy: 0.4863 - state_x_loss: 1.3605 - state_y_accuracy: 0.5200 - state_y_loss: 1.3227
# Epoch 46/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.6441 - state_x_accuracy: 0.4988 - state_x_loss: 1.3277 - state_y_accuracy: 0.5350 - state_y_loss: 1.3165
# Epoch 47/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.5980 - state_x_accuracy: 0.5075 - state_x_loss: 1.3208 - state_y_accuracy: 0.5525 - state_y_loss: 1.2772
# Epoch 48/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.5654 - state_x_accuracy: 0.4938 - state_x_loss: 1.3093 - state_y_accuracy: 0.5387 - state_y_loss: 1.2561
# Epoch 49/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.5541 - state_x_accuracy: 0.5038 - state_x_loss: 1.2863 - state_y_accuracy: 0.5275 - state_y_loss: 1.2677
# Epoch 50/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.5344 - state_x_accuracy: 0.5088 - state_x_loss: 1.2909 - state_y_accuracy: 0.5612 - state_y_loss: 1.2435
# Epoch 51/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.5225 - state_x_accuracy: 0.5050 - state_x_loss: 1.2835 - state_y_accuracy: 0.5437 - state_y_loss: 1.2389
# Epoch 52/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.5030 - state_x_accuracy: 0.5075 - state_x_loss: 1.2850 - state_y_accuracy: 0.5600 - state_y_loss: 1.2180
# Epoch 53/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.4566 - state_x_accuracy: 0.5125 - state_x_loss: 1.2640 - state_y_accuracy: 0.5763 - state_y_loss: 1.1926
# Epoch 54/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.3925 - state_x_accuracy: 0.5100 - state_x_loss: 1.2323 - state_y_accuracy: 0.5888 - state_y_loss: 1.1602
# Epoch 55/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.3580 - state_x_accuracy: 0.5512 - state_x_loss: 1.2091 - state_y_accuracy: 0.5975 - state_y_loss: 1.1490
# Epoch 56/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.3418 - state_x_accuracy: 0.5113 - state_x_loss: 1.2068 - state_y_accuracy: 0.6037 - state_y_loss: 1.1350
# Epoch 57/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.2849 - state_x_accuracy: 0.5587 - state_x_loss: 1.1738 - state_y_accuracy: 0.6100 - state_y_loss: 1.1112
# Epoch 58/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.2419 - state_x_accuracy: 0.5425 - state_x_loss: 1.1729 - state_y_accuracy: 0.6513 - state_y_loss: 1.0690
# Epoch 59/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.2764 - state_x_accuracy: 0.5462 - state_x_loss: 1.1810 - state_y_accuracy: 0.5838 - state_y_loss: 1.0954
# Epoch 60/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.2490 - state_x_accuracy: 0.5400 - state_x_loss: 1.1729 - state_y_accuracy: 0.6400 - state_y_loss: 1.0761
# Epoch 61/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.1721 - state_x_accuracy: 0.5400 - state_x_loss: 1.1462 - state_y_accuracy: 0.6538 - state_y_loss: 1.0259
# Epoch 62/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.1802 - state_x_accuracy: 0.5400 - state_x_loss: 1.1553 - state_y_accuracy: 0.6488 - state_y_loss: 1.0249
# Epoch 63/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.1580 - state_x_accuracy: 0.5612 - state_x_loss: 1.1388 - state_y_accuracy: 0.6450 - state_y_loss: 1.0192
# Epoch 64/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.1191 - state_x_accuracy: 0.5700 - state_x_loss: 1.1141 - state_y_accuracy: 0.6400 - state_y_loss: 1.0050
# Epoch 65/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.0770 - state_x_accuracy: 0.5875 - state_x_loss: 1.0728 - state_y_accuracy: 0.6612 - state_y_loss: 1.0042
# Epoch 66/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.0354 - state_x_accuracy: 0.6000 - state_x_loss: 1.0594 - state_y_accuracy: 0.6488 - state_y_loss: 0.9760
# Epoch 67/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.9868 - state_x_accuracy: 0.6100 - state_x_loss: 1.0479 - state_y_accuracy: 0.6675 - state_y_loss: 0.9390
# Epoch 68/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9812 - state_x_accuracy: 0.6012 - state_x_loss: 1.0324 - state_y_accuracy: 0.6662 - state_y_loss: 0.9489
# Epoch 69/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.9569 - state_x_accuracy: 0.5875 - state_x_loss: 1.0309 - state_y_accuracy: 0.6850 - state_y_loss: 0.9260
# Epoch 70/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.9396 - state_x_accuracy: 0.6137 - state_x_loss: 1.0057 - state_y_accuracy: 0.6837 - state_y_loss: 0.9339
# Epoch 71/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.8965 - state_x_accuracy: 0.6325 - state_x_loss: 0.9830 - state_y_accuracy: 0.6837 - state_y_loss: 0.9135
# Epoch 72/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.8609 - state_x_accuracy: 0.6263 - state_x_loss: 0.9766 - state_y_accuracy: 0.6800 - state_y_loss: 0.8843
# Epoch 73/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.8270 - state_x_accuracy: 0.6438 - state_x_loss: 0.9575 - state_y_accuracy: 0.6900 - state_y_loss: 0.8695
# Epoch 74/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.8388 - state_x_accuracy: 0.6425 - state_x_loss: 0.9470 - state_y_accuracy: 0.6825 - state_y_loss: 0.8918
# Epoch 75/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.7956 - state_x_accuracy: 0.6350 - state_x_loss: 0.9471 - state_y_accuracy: 0.7200 - state_y_loss: 0.8485
# Epoch 76/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.8246 - state_x_accuracy: 0.6200 - state_x_loss: 0.9755 - state_y_accuracy: 0.7138 - state_y_loss: 0.8491
# Epoch 77/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.8145 - state_x_accuracy: 0.6300 - state_x_loss: 0.9601 - state_y_accuracy: 0.7050 - state_y_loss: 0.8544
# Epoch 78/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.7831 - state_x_accuracy: 0.6413 - state_x_loss: 0.9357 - state_y_accuracy: 0.7138 - state_y_loss: 0.8474
# Epoch 79/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.7461 - state_x_accuracy: 0.6575 - state_x_loss: 0.9034 - state_y_accuracy: 0.7038 - state_y_loss: 0.8427
# Epoch 80/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.7242 - state_x_accuracy: 0.6587 - state_x_loss: 0.9007 - state_y_accuracy: 0.7250 - state_y_loss: 0.8235
# Epoch 81/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.6744 - state_x_accuracy: 0.6538 - state_x_loss: 0.8924 - state_y_accuracy: 0.7412 - state_y_loss: 0.7821
# Epoch 82/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.6447 - state_x_accuracy: 0.6725 - state_x_loss: 0.8612 - state_y_accuracy: 0.7200 - state_y_loss: 0.7835
# Epoch 83/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5994 - state_x_accuracy: 0.7025 - state_x_loss: 0.8414 - state_y_accuracy: 0.7563 - state_y_loss: 0.7580
# Epoch 84/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.6050 - state_x_accuracy: 0.6862 - state_x_loss: 0.8445 - state_y_accuracy: 0.7450 - state_y_loss: 0.7605
# Epoch 85/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.6069 - state_x_accuracy: 0.6787 - state_x_loss: 0.8580 - state_y_accuracy: 0.7525 - state_y_loss: 0.7489
# Epoch 86/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.6279 - state_x_accuracy: 0.7038 - state_x_loss: 0.8545 - state_y_accuracy: 0.7350 - state_y_loss: 0.7735
# Epoch 87/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5900 - state_x_accuracy: 0.6625 - state_x_loss: 0.8496 - state_y_accuracy: 0.7487 - state_y_loss: 0.7404
# Epoch 88/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5430 - state_x_accuracy: 0.6988 - state_x_loss: 0.8260 - state_y_accuracy: 0.7638 - state_y_loss: 0.7171
# Epoch 89/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5554 - state_x_accuracy: 0.6787 - state_x_loss: 0.8335 - state_y_accuracy: 0.7700 - state_y_loss: 0.7219
# Epoch 90/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5032 - state_x_accuracy: 0.7275 - state_x_loss: 0.7915 - state_y_accuracy: 0.7500 - state_y_loss: 0.7117
# Epoch 91/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5076 - state_x_accuracy: 0.7375 - state_x_loss: 0.7855 - state_y_accuracy: 0.7525 - state_y_loss: 0.7220
# Epoch 92/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4906 - state_x_accuracy: 0.7237 - state_x_loss: 0.7799 - state_y_accuracy: 0.7713 - state_y_loss: 0.7107
# Epoch 93/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4967 - state_x_accuracy: 0.7200 - state_x_loss: 0.7953 - state_y_accuracy: 0.7588 - state_y_loss: 0.7014
# Epoch 94/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4547 - state_x_accuracy: 0.7375 - state_x_loss: 0.7536 - state_y_accuracy: 0.7525 - state_y_loss: 0.7012
# Epoch 95/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4332 - state_x_accuracy: 0.7400 - state_x_loss: 0.7391 - state_y_accuracy: 0.7625 - state_y_loss: 0.6941
# Epoch 96/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4325 - state_x_accuracy: 0.7550 - state_x_loss: 0.7331 - state_y_accuracy: 0.7487 - state_y_loss: 0.6994
# Epoch 97/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3943 - state_x_accuracy: 0.7375 - state_x_loss: 0.7326 - state_y_accuracy: 0.7800 - state_y_loss: 0.6617
# Epoch 98/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.3666 - state_x_accuracy: 0.7325 - state_x_loss: 0.7288 - state_y_accuracy: 0.7912 - state_y_loss: 0.6379
# Epoch 99/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.3737 - state_x_accuracy: 0.7350 - state_x_loss: 0.7316 - state_y_accuracy: 0.7825 - state_y_loss: 0.6421
# Epoch 100/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.3655 - state_x_accuracy: 0.7337 - state_x_loss: 0.7168 - state_y_accuracy: 0.7725 - state_y_loss: 0.6486
# Epoch 101/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.3573 - state_x_accuracy: 0.7575 - state_x_loss: 0.7051 - state_y_accuracy: 0.7788 - state_y_loss: 0.6522
# Epoch 102/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.3133 - state_x_accuracy: 0.7738 - state_x_loss: 0.6886 - state_y_accuracy: 0.7862 - state_y_loss: 0.6246
# Epoch 103/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.2996 - state_x_accuracy: 0.7588 - state_x_loss: 0.6986 - state_y_accuracy: 0.8050 - state_y_loss: 0.6010
# Epoch 104/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1
# Epoch 199/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5638 - state_x_accuracy: 0.9062 - state_x_loss: 0.2907 - state_y_accuracy: 0.9200 - state_y_loss: 0.2731
# Epoch 200/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5811 - state_x_accuracy: 0.8963 - state_x_loss: 0.3153 - state_y_accuracy: 0.9112 - state_y_loss: 0.2658
# Epoch 1/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.4066 - state_x_accuracy: 0.3363 - state_x_loss: 2.9594 - state_y_accuracy: 0.3512 - state_y_loss: 2.4472
# Epoch 2/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.0126 - state_x_accuracy: 0.5525 - state_x_loss: 1.4028 - state_y_accuracy: 0.4712 - state_y_loss: 1.6098
# Epoch 3/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.2622 - state_x_accuracy: 0.5462 - state_x_loss: 1.1084 - state_y_accuracy: 0.5475 - state_y_loss: 1.1539
# Epoch 4/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.8603 - state_x_accuracy: 0.6288 - state_x_loss: 0.8830 - state_y_accuracy: 0.5962 - state_y_loss: 0.9773
# Epoch 5/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.6875 - state_x_accuracy: 0.6787 - state_x_loss: 0.7879 - state_y_accuracy: 0.6300 - state_y_loss: 0.8996
# Epoch 6/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5879 - state_x_accuracy: 0.7038 - state_x_loss: 0.7284 - state_y_accuracy: 0.6463 - state_y_loss: 0.8595
# Epoch 7/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5346 - state_x_accuracy: 0.7113 - state_x_loss: 0.7187 - state_y_accuracy: 0.6737 - state_y_loss: 0.8160
# Epoch 8/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4620 - state_x_accuracy: 0.7175 - state_x_loss: 0.6936 - state_y_accuracy: 0.6687 - state_y_loss: 0.7685
# Epoch 9/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3385 - state_x_accuracy: 0.7725 - state_x_loss: 0.6080 - state_y_accuracy: 0.6975 - state_y_loss: 0.7305
# Epoch 10/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2739 - state_x_accuracy: 0.7887 - state_x_loss: 0.5861 - state_y_accuracy: 0.7063 - state_y_loss: 0.6878
# Epoch 11/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2715 - state_x_accuracy: 0.7688 - state_x_loss: 0.5962 - state_y_accuracy: 0.7138 - state_y_loss: 0.6753
# Epoch 12/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1955 - state_x_accuracy: 0.8125 - state_x_loss: 0.5540 - state_y_accuracy: 0.7237 - state_y_loss: 0.6414
# Epoch 13/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1343 - state_x_accuracy: 0.8138 - state_x_loss: 0.5284 - state_y_accuracy: 0.7487 - state_y_loss: 0.6059
# Epoch 14/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1561 - state_x_accuracy: 0.7950 - state_x_loss: 0.5507 - state_y_accuracy: 0.7525 - state_y_loss: 0.6053
# Epoch 15/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1341 - state_x_accuracy: 0.7962 - state_x_loss: 0.5420 - state_y_accuracy: 0.7650 - state_y_loss: 0.5922
# Epoch 16/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1761 - state_x_accuracy: 0.7837 - state_x_loss: 0.5614 - state_y_accuracy: 0.7625 - state_y_loss: 0.6147
# Epoch 17/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1507 - state_x_accuracy: 0.8012 - state_x_loss: 0.5411 - state_y_accuracy: 0.7487 - state_y_loss: 0.6096
# Epoch 18/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0957 - state_x_accuracy: 0.8138 - state_x_loss: 0.5162 - state_y_accuracy: 0.7713 - state_y_loss: 0.5795
# Epoch 19/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0484 - state_x_accuracy: 0.8375 - state_x_loss: 0.4856 - state_y_accuracy: 0.7738 - state_y_loss: 0.5628
# Epoch 20/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0804 - state_x_accuracy: 0.8112 - state_x_loss: 0.5158 - state_y_accuracy: 0.7750 - state_y_loss: 0.5647
# Epoch 21/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0451 - state_x_accuracy: 0.8213 - state_x_loss: 0.4979 - state_y_accuracy: 0.7700 - state_y_loss: 0.5471
# Epoch 22/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0135 - state_x_accuracy: 0.8575 - state_x_loss: 0.4554 - state_y_accuracy: 0.7663 - state_y_loss: 0.5581
# Epoch 23/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9924 - state_x_accuracy: 0.8575 - state_x_loss: 0.4525 - state_y_accuracy: 0.7837 - state_y_loss: 0.5399
# Epoch 24/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0305 - state_x_accuracy: 0.8275 - state_x_loss: 0.4813 - state_y_accuracy: 0.7825 - state_y_loss: 0.5492
# Epoch 25/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9865 - state_x_accuracy: 0.8413 - state_x_loss: 0.4677 - state_y_accuracy: 0.7950 - state_y_loss: 0.5189
# Epoch 26/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9430 - state_x_accuracy: 0.8625 - state_x_loss: 0.4398 - state_y_accuracy: 0.8138 - state_y_loss: 0.5032
# Epoch 27/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9146 - state_x_accuracy: 0.8750 - state_x_loss: 0.4303 - state_y_accuracy: 0.8313 - state_y_loss: 0.4843
# Epoch 28/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9204 - state_x_accuracy: 0.8675 - state_x_loss: 0.4330 - state_y_accuracy: 0.8050 - state_y_loss: 0.4874
# Epoch 29/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9506 - state_x_accuracy: 0.8712 - state_x_loss: 0.4458 - state_y_accuracy: 0.7975 - state_y_loss: 0.5048
# Epoch 30/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9438 - state_x_accuracy: 0.8462 - state_x_loss: 0.4611 - state_y_accuracy: 0.8313 - state_y_loss: 0.4827
# Epoch 31/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8956 - state_x_accuracy: 0.8587 - state_x_loss: 0.4387 - state_y_accuracy: 0.8400 - state_y_loss: 0.4569
# Epoch 32/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8869 - state_x_accuracy: 0.8700 - state_x_loss: 0.4177 - state_y_accuracy: 0.8375 - state_y_loss: 0.4692
# Epoch 33/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8895 - state_x_accuracy: 0.8612 - state_x_loss: 0.4354 - state_y_accuracy: 0.8512 - state_y_loss: 0.4541
# Epoch 34/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8800 - state_x_accuracy: 0.8763 - state_x_loss: 0.4276 - state_y_accuracy: 0.8413 - state_y_loss: 0.4524
# Epoch 35/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8822 - state_x_accuracy: 0.8575 - state_x_loss: 0.4306 - state_y_accuracy: 0.8325 - state_y_loss: 0.4516
# Epoch 36/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8483 - state_x_accuracy: 0.8637 - state_x_loss: 0.4198 - state_y_accuracy: 0.8512 - state_y_loss: 0.4285
# Epoch 37/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8711 - state_x_accuracy: 0.8550 - state_x_loss: 0.4223 - state_y_accuracy: 0.8375 - state_y_loss: 0.4488
# Epoch 38/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8496 - state_x_accuracy: 0.8763 - state_x_loss: 0.3970 - state_y_accuracy: 0.8313 - state_y_loss: 0.4527
# Epoch 39/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8250 - state_x_accuracy: 0.8775 - state_x_loss: 0.4064 - state_y_accuracy: 0.8550 - state_y_loss: 0.4186
# Epoch 40/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.8293 - state_x_accuracy: 0.8813 - state_x_loss: 0.3994 - state_y_accuracy: 0.8438 - state_y_loss: 0.4299
# Epoch 41/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8176 - state_x_accuracy: 0.8813 - state_x_loss: 0.3935 - state_y_accuracy: 0.8512 - state_y_loss: 0.4241
# Epoch 42/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8003 - state_x_accuracy: 0.8875 - state_x_loss: 0.3817 - state_y_accuracy: 0.8487 - state_y_loss: 0.4186
# Epoch 43/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8348 - state_x_accuracy: 0.8675 - state_x_loss: 0.3942 - state_y_accuracy: 0.8500 - state_y_loss: 0.4407
# Epoch 44/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8086 - state_x_accuracy: 0.8637 - state_x_loss: 0.3898 - state_y_accuracy: 0.8487 - state_y_loss: 0.4188
# Epoch 45/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7673 - state_x_accuracy: 0.8963 - state_x_loss: 0.3641 - state_y_accuracy: 0.8562 - state_y_loss: 0.4032
# Epoch 46/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7610 - state_x_accuracy: 0.9000 - state_x_loss: 0.3637 - state_y_accuracy: 0.8712 - state_y_loss: 0.3973
# Epoch 47/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7946 - state_x_accuracy: 0.8938 - state_x_loss: 0.3700 - state_y_accuracy: 0.8550 - state_y_loss: 0.4246
# Epoch 48/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7796 - state_x_accuracy: 0.8813 - state_x_loss: 0.3823 - state_y_accuracy: 0.8625 - state_y_loss: 0.3973
# Epoch 49/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7593 - state_x_accuracy: 0.8825 - state_x_loss: 0.3737 - state_y_accuracy: 0.8775 - state_y_loss: 0.3856
# Epoch 50/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7311 - state_x_accuracy: 0.9000 - state_x_loss: 0.3469 - state_y_accuracy: 0.8838 - state_y_loss: 0.3843
# Epoch 51/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7217 - state_x_accuracy: 0.9025 - state_x_loss: 0.3453 - state_y_accuracy: 0.8813 - state_y_loss: 0.3764
# Epoch 52/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7366 - state_x_accuracy: 0.9000 - state_x_loss: 0.3400 - state_y_accuracy: 0.8575 - state_y_loss: 0.3966
# Epoch 53/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7544 - state_x_accuracy: 0.8988 - state_x_loss: 0.3587 - state_y_accuracy: 0.8462 - state_y_loss: 0.3957
# Epoch 54/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7033 - state_x_accuracy: 0.8888 - state_x_loss: 0.3379 - state_y_accuracy: 0.8750 - state_y_loss: 0.3654
# Epoch 55/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7377 - state_x_accuracy: 0.9000 - state_x_loss: 0.3529 - state_y_accuracy: 0.8612 - state_y_loss: 0.3849
# Epoch 56/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6822 - state_x_accuracy: 0.9225 - state_x_loss: 0.3200 - state_y_accuracy: 0.8675 - state_y_loss: 0.3621
# Epoch 57/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6882 - state_x_accuracy: 0.8938 - state_x_loss: 0.3331 - state_y_accuracy: 0.8850 - state_y_loss: 0.3551
# Epoch 58/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6916 - state_x_accuracy: 0.9013 - state_x_loss: 0.3408 - state_y_accuracy: 0.8888 - state_y_loss: 0.3509
# Epoch 59/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7011 - state_x_accuracy: 0.9025 - state_x_loss: 0.3452 - state_y_accuracy: 0.8712 - state_y_loss: 0.3559
# Epoch 60/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6593 - state_x_accuracy: 0.9125 - state_x_loss: 0.3170 - state_y_accuracy: 0.8925 - state_y_loss: 0.3423
# Epoch 61/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6578 - state_x_accuracy: 0.9175 - state_x_loss: 0.3206 - state_y_accuracy: 0.9025 - state_y_loss: 0.3372
# Epoch 62/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6901 - state_x_accuracy: 0.9187 - state_x_loss: 0.3182 - state_y_accuracy: 0.8637 - state_y_loss: 0.3719
# Epoch 63/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6923 - state_x_accuracy: 0.9050 - state_x_loss: 0.3430 - state_y_accuracy: 0.8875 - state_y_loss: 0.3493
# Epoch 64/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6693 - state_x_accuracy: 0.8938 - state_x_loss: 0.3355 - state_y_accuracy: 0.9062 - state_y_loss: 0.3338
# Epoch 65/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6433 - state_x_accuracy: 0.9075 - state_x_loss: 0.3208 - state_y_accuracy: 0.9050 - state_y_loss: 0.3224
# Epoch 66/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6132 - state_x_accuracy: 0.9212 - state_x_loss: 0.2953 - state_y_accuracy: 0.9075 - state_y_loss: 0.3179
# Epoch 67/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6252 - state_x_accuracy: 0.9337 - state_x_loss: 0.2959 - state_y_accuracy: 0.8938 - state_y_loss: 0.3293
# Epoch 68/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.6307 - state_x_accuracy: 0.9175 - state_x_loss: 0.3125 - state_y_accuracy: 0.9000 - state_y_loss: 0.3182
# Epoch 69/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6411 - state_x_accuracy: 0.9013 - state_x_loss: 0.3134 - state_y_accuracy: 0.8925 - state_y_loss: 0.3276
# Epoch 70/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6833 - state_x_accuracy: 0.8900 - state_x_loss: 0.3336 - state_y_accuracy: 0.8813 - state_y_loss: 0.3497
# Epoch 71/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6130 - state_x_accuracy: 0.9187 - state_x_loss: 0.3014 - state_y_accuracy: 0.9100 - state_y_loss: 0.3115
# Epoch 72/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6001 - state_x_accuracy: 0.9250 - state_x_loss: 0.2899 - state_y_accuracy: 0.9162 - state_y_loss: 0.3103
# Epoch 73/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5939 - state_x_accuracy: 0.9200 - state_x_loss: 0.2947 - state_y_accuracy: 0.9112 - state_y_loss: 0.2992
# Epoch 74/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6071 - state_x_accuracy: 0.9287 - state_x_loss: 0.2874 - state_y_accuracy: 0.9025 - state_y_loss: 0.3196
# Epoch 75/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6091 - state_x_accuracy: 0.9200 - state_x_loss: 0.2981 - state_y_accuracy: 0.9062 - state_y_loss: 0.3111
# Epoch 76/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6180 - state_x_accuracy: 0.9312 - state_x_loss: 0.2812 - state_y_accuracy: 0.8850 - state_y_loss: 0.3368
# Epoch 77/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6172 - state_x_accuracy: 0.9262 - state_x_loss: 0.2718 - state_y_accuracy: 0.8900 - state_y_loss: 0.3454
# Epoch 78/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6272 - state_x_accuracy: 0.9025 - state_x_loss: 0.3172 - state_y_accuracy: 0.9062 - state_y_loss: 0.3101
# Epoch 79/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6853 - state_x_accuracy: 0.8888 - state_x_loss: 0.3275 - state_y_accuracy: 0.8712 - state_y_loss: 0.3578
# Epoch 80/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5941 - state_x_accuracy: 0.9350 - state_x_loss: 0.2724 - state_y_accuracy: 0.9025 - state_y_loss: 0.3217
# Epoch 81/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6240 - state_x_accuracy: 0.9187 - state_x_loss: 0.2970 - state_y_accuracy: 0.8925 - state_y_loss: 0.3270
# Epoch 82/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6116 - state_x_accuracy: 0.9125 - state_x_loss: 0.2865 - state_y_accuracy: 0.8800 - state_y_loss: 0.3251
# Epoch 83/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.6093 - state_x_accuracy: 0.9100 - state_x_loss: 0.2984 - state_y_accuracy: 0.9025 - state_y_loss: 0.3109
# Epoch 84/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5659 - state_x_accuracy: 0.9137 - state_x_loss: 0.2796 - state_y_accuracy: 0.9150 - state_y_loss: 0.2862
# Epoch 85/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.6008 - state_x_accuracy: 0.8850 - state_x_loss: 0.3295 - state_y_accuracy: 0.9300 - state_y_loss: 0.2713
# Epoch 86/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5760 - state_x_accuracy: 0.9125 - state_x_loss: 0.2896 - state_y_accuracy: 0.9137 - state_y_loss: 0.2864
# Epoch 87/200
# ...
# Epoch 106/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4492 - state_x_accuracy: 0.9438 - state_x_loss: 0.2200 - state_y_accuracy: 0.9450 - state_y_loss: 0.2292
# Epoch 107/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4883 - state_x_accuracy: 0.9300 - state_x_loss: 0.2499 - state_y_accuracy: 0.9438 - state_y_loss: 0.2384
# Epoch 108/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5047 - state_x_accuracy: 0.9350 - state_x_loss: 0.2293 - state_y_accuracy: 0.9075 - state_y_loss: 0.2753
# Epoch 109/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4993 - state_x_accuracy: 0.9475 - state_x_loss: 0.2239 - state_y_accuracy: 0.9087 - state_y_loss: 0.2755
# Epoch 110/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4606 - state_x_accuracy: 0.9450 - state_x_loss: 0.2263 - state_y_accuracy: 0.9438 - state_y_loss: 0.2343
# Epoch 111/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4845 - state_x_accuracy: 0.9362 - state_x_loss: 0.2416 - state_y_accuracy: 0.9312 - state_y_loss: 0.2429
# Epoch 112/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4744 - state_x_accuracy: 0.9337 - state_x_loss: 0.2379 - state_y_accuracy: 0.9400 - state_y_loss: 0.2365
# Epoch 113/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4528 - state_x_accuracy: 0.9413 - state_x_loss: 0.2304 - state_y_accuracy: 0.9500 - state_y_loss: 0.2224
# Epoch 114/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4891 - state_x_accuracy: 0.9375 - state_x_loss: 0.2425 - state_y_accuracy: 0.9212 - state_y_loss: 0.2465
# Epoch 115/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4720 - state_x_accuracy: 0.9488 - state_x_loss: 0.2256 - state_y_accuracy: 0.9162 - state_y_loss: 0.2464
# Epoch 116/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4412 - state_x_accuracy: 0.9488 - state_x_loss: 0.2097 - state_y_accuracy: 0.9413 - state_y_loss: 0.2315
# Epoch 117/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4383 - state_x_accuracy: 0.9463 - state_x_loss: 0.2174 - state_y_accuracy: 0.9488 - state_y_loss: 0.2209
# Epoch 118/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4767 - state_x_accuracy: 0.9300 - state_x_loss: 0.2424 - state_y_accuracy: 0.9312 - state_y_loss: 0.2343
# Epoch 119/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4774 - state_x_accuracy: 0.9375 - state_x_loss: 0.2249 - state_y_accuracy: 0.9125 - state_y_loss: 0.2525
# Epoch 120/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4637 - state_x_accuracy: 0.9475 - state_x_loss: 0.2138 - state_y_accuracy: 0.9237 - state_y_loss: 0.2499
# Epoch 121/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4300 - state_x_accuracy: 0.9575 - state_x_loss: 0.2023 - state_y_accuracy: 0.9500 - state_y_loss: 0.2277
# Epoch 122/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4182 - state_x_accuracy: 0.9575 - state_x_loss: 0.2047 - state_y_accuracy: 0.9475 - state_y_loss: 0.2135
# Epoch 123/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4465 - state_x_accuracy: 0.9488 - state_x_loss: 0.2239 - state_y_accuracy: 0.9337 - state_y_loss: 0.2226
# Epoch 124/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4611 - state_x_accuracy: 0.9438 - state_x_loss: 0.2276 - state_y_accuracy: 0.9337 - state_y_loss: 0.2335
# Epoch 125/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4538 - state_x_accuracy: 0.9262 - state_x_loss: 0.2277 - state_y_accuracy: 0.9438 - state_y_loss: 0.2261
# Epoch 126/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4987 - state_x_accuracy: 0.9175 - state_x_loss: 0.2561 - state_y_accuracy: 0.9237 - state_y_loss: 0.2425
# Epoch 127/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4473 - state_x_accuracy: 0.9312 - state_x_loss: 0.2224 - state_y_accuracy: 0.9413 - state_y_loss: 0.2249
# Epoch 128/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4103 - state_x_accuracy: 0.9450 - state_x_loss: 0.2042 - state_y_accuracy: 0.9550 - state_y_loss: 0.2061
# Epoch 129/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4152 - state_x_accuracy: 0.9550 - state_x_loss: 0.1993 - state_y_accuracy: 0.9413 - state_y_loss: 0.2159
# Epoch 130/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4118 - state_x_accuracy: 0.9538 - state_x_loss: 0.1961 - state_y_accuracy: 0.9425 - state_y_loss: 0.2157
# Epoch 131/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4064 - state_x_accuracy: 0.9475 - state_x_loss: 0.2051 - state_y_accuracy: 0.9563 - state_y_loss: 0.2013
# Epoch 132/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4315 - state_x_accuracy: 0.9262 - state_x_loss: 0.2313 - state_y_accuracy: 0.9538 - state_y_loss: 0.2002
# Epoch 133/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4011 - state_x_accuracy: 0.9563 - state_x_loss: 0.1984 - state_y_accuracy: 0.9538 - state_y_loss: 0.2027
# Epoch 134/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3895 - state_x_accuracy: 0.9463 - state_x_loss: 0.1949 - state_y_accuracy: 0.9500 - state_y_loss: 0.1946
# Epoch 135/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4140 - state_x_accuracy: 0.9388 - state_x_loss: 0.2110 - state_y_accuracy: 0.9563 - state_y_loss: 0.2030
# Epoch 136/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3961 - state_x_accuracy: 0.9463 - state_x_loss: 0.1996 - state_y_accuracy: 0.9563 - state_y_loss: 0.1965
# Epoch 137/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3736 - state_x_accuracy: 0.9488 - state_x_loss: 0.1902 - state_y_accuracy: 0.9638 - state_y_loss: 0.1834
# Epoch 138/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4094 - state_x_accuracy: 0.9312 - state_x_loss: 0.2151 - state_y_accuracy: 0.9513 - state_y_loss: 0.1943
# Epoch 139/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4051 - state_x_accuracy: 0.9375 - state_x_loss: 0.2171 - state_y_accuracy: 0.9625 - state_y_loss: 0.1880
# Epoch 140/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3917 - state_x_accuracy: 0.9425 - state_x_loss: 0.1955 - state_y_accuracy: 0.9488 - state_y_loss: 0.1961
# Epoch 141/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3977 - state_x_accuracy: 0.9438 - state_x_loss: 0.2001 - state_y_accuracy: 0.9550 - state_y_loss: 0.1977
# Epoch 142/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4421 - state_x_accuracy: 0.9425 - state_x_loss: 0.2122 - state_y_accuracy: 0.9337 - state_y_loss: 0.2299
# Epoch 143/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4155 - state_x_accuracy: 0.9513 - state_x_loss: 0.1905 - state_y_accuracy: 0.9337 - state_y_loss: 0.2251
# Epoch 144/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4201 - state_x_accuracy: 0.9488 - state_x_loss: 0.2027 - state_y_accuracy: 0.9438 - state_y_loss: 0.2174
# Epoch 145/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3747 - state_x_accuracy: 0.9513 - state_x_loss: 0.1878 - state_y_accuracy: 0.9563 - state_y_loss: 0.1869
# Epoch 146/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4053 - state_x_accuracy: 0.9325 - state_x_loss: 0.2120 - state_y_accuracy: 0.9563 - state_y_loss: 0.1933
# Epoch 147/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4269 - state_x_accuracy: 0.9325 - state_x_loss: 0.2212 - state_y_accuracy: 0.9362 - state_y_loss: 0.2058
# Epoch 148/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3595 - state_x_accuracy: 0.9663 - state_x_loss: 0.1665 - state_y_accuracy: 0.9425 - state_y_loss: 0.1931
# Epoch 149/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3518 - state_x_accuracy: 0.9563 - state_x_loss: 0.1703 - state_y_accuracy: 0.9588 - state_y_loss: 0.1815
# Epoch 150/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4224 - state_x_accuracy: 0.9388 - state_x_loss: 0.2062 - state_y_accuracy: 0.9337 - state_y_loss: 0.2162
# Epoch 151/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4126 - state_x_accuracy: 0.9425 - state_x_loss: 0.1984 - state_y_accuracy: 0.9450 - state_y_loss: 0.2143
# Epoch 152/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3741 - state_x_accuracy: 0.9550 - state_x_loss: 0.1801 - state_y_accuracy: 0.9450 - state_y_loss: 0.1940
# Epoch 153/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3628 - state_x_accuracy: 0.9500 - state_x_loss: 0.1882 - state_y_accuracy: 0.9588 - state_y_loss: 0.1746
# Epoch 154/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3460 - state_x_accuracy: 0.9538 - state_x_loss: 0.1736 - state_y_accuracy: 0.9638 - state_y_loss: 0.1725
# Epoch 155/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3602 - state_x_accuracy: 0.9488 - state_x_loss: 0.1855 - state_y_accuracy: 0.9638 - state_y_loss: 0.1747
# Epoch 156/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3508 - state_x_accuracy: 0.9525 - state_x_loss: 0.1730 - state_y_accuracy: 0.9475 - state_y_loss: 0.1778
# Epoch 157/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3767 - state_x_accuracy: 0.9488 - state_x_loss: 0.1850 - state_y_accuracy: 0.9475 - state_y_loss: 0.1917
# Epoch 158/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3414 - state_x_accuracy: 0.9712 - state_x_loss: 0.1610 - state_y_accuracy: 0.9538 - state_y_loss: 0.1804
# Epoch 159/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3421 - state_x_accuracy: 0.9500 - state_x_loss: 0.1692 - state_y_accuracy: 0.9650 - state_y_loss: 0.1729
# Epoch 160/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3228 - state_x_accuracy: 0.9700 - state_x_loss: 0.1613 - state_y_accuracy: 0.9712 - state_y_loss: 0.1615
# Epoch 161/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3365 - state_x_accuracy: 0.9638 - state_x_loss: 0.1686 - state_y_accuracy: 0.9625 - state_y_loss: 0.1679
# Epoch 162/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3364 - state_x_accuracy: 0.9613 - state_x_loss: 0.1666 - state_y_accuracy: 0.9575 - state_y_loss: 0.1698
# Epoch 163/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3551 - state_x_accuracy: 0.9500 - state_x_loss: 0.1838 - state_y_accuracy: 0.9563 - state_y_loss: 0.1713
# Epoch 164/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3120 - state_x_accuracy: 0.9663 - state_x_loss: 0.1476 - state_y_accuracy: 0.9663 - state_y_loss: 0.1644
# Epoch 165/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3473 - state_x_accuracy: 0.9613 - state_x_loss: 0.1601 - state_y_accuracy: 0.9425 - state_y_loss: 0.1872
# Epoch 166/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3239 - state_x_accuracy: 0.9688 - state_x_loss: 0.1496 - state_y_accuracy: 0.9588 - state_y_loss: 0.1743
# Epoch 167/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3109 - state_x_accuracy: 0.9663 - state_x_loss: 0.1528 - state_y_accuracy: 0.9650 - state_y_loss: 0.1581
# Epoch 168/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3139 - state_x_accuracy: 0.9675 - state_x_loss: 0.1496 - state_y_accuracy: 0.9538 - state_y_loss: 0.1643
# Epoch 169/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3434 - state_x_accuracy: 0.9625 - state_x_loss: 0.1645 - state_y_accuracy: 0.9488 - state_y_loss: 0.1789
# Epoch 170/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3480 - state_x_accuracy: 0.9463 - state_x_loss: 0.1799 - state_y_accuracy: 0.9613 - state_y_loss: 0.1681
# Epoch 171/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3475 - state_x_accuracy: 0.9413 - state_x_loss: 0.1874 - state_y_accuracy: 0.9588 - state_y_loss: 0.1600
# Epoch 172/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3164 - state_x_accuracy: 0.9650 - state_x_loss: 0.1530 - state_y_accuracy: 0.9613 - state_y_loss: 0.1634
# Epoch 173/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3305 - state_x_accuracy: 0.9538 - state_x_loss: 0.1593 - state_y_accuracy: 0.9563 - state_y_loss: 0.1712
# Epoch 174/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3279 - state_x_accuracy: 0.9613 - state_x_loss: 0.1709 - state_y_accuracy: 0.9563 - state_y_loss: 0.1571
# Epoch 175/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3221 - state_x_accuracy: 0.9488 - state_x_loss: 0.1651 - state_y_accuracy: 0.9663 - state_y_loss: 0.1570
# Epoch 176/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3461 - state_x_accuracy: 0.9463 - state_x_loss: 0.1832 - state_y_accuracy: 0.9625 - state_y_loss: 0.1629
# Epoch 177/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3217 - state_x_accuracy: 0.9600 - state_x_loss: 0.1575 - state_y_accuracy: 0.9663 - state_y_loss: 0.1641
# Epoch 178/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3183 - state_x_accuracy: 0.9575 - state_x_loss: 0.1536 - state_y_accuracy: 0.9525 - state_y_loss: 0.1647
# Epoch 179/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.3148 - state_x_accuracy: 0.9575 - state_x_loss: 0.1643 - state_y_accuracy: 0.9712 - state_y_loss: 0.1505
# Epoch 180/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3053 - state_x_accuracy: 0.9600 - state_x_loss: 0.1464 - state_y_accuracy: 0.9613 - state_y_loss: 0.1589
# Epoch 181/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2905 - state_x_accuracy: 0.9650 - state_x_loss: 0.1384 - state_y_accuracy: 0.9600 - state_y_loss: 0.1521
# Epoch 182/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3050 - state_x_accuracy: 0.9625 - state_x_loss: 0.1498 - state_y_accuracy: 0.9575 - state_y_loss: 0.1552
# Epoch 183/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2795 - state_x_accuracy: 0.9700 - state_x_loss: 0.1433 - state_y_accuracy: 0.9737 - state_y_loss: 0.1362
# Epoch 184/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2715 - state_x_accuracy: 0.9712 - state_x_loss: 0.1310 - state_y_accuracy: 0.9712 - state_y_loss: 0.1405
# Epoch 185/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.3135 - state_x_accuracy: 0.9625 - state_x_loss: 0.1495 - state_y_accuracy: 0.9588 - state_y_loss: 0.1640
# Epoch 186/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3034 - state_x_accuracy: 0.9638 - state_x_loss: 0.1472 - state_y_accuracy: 0.9588 - state_y_loss: 0.1562
# Epoch 187/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2918 - state_x_accuracy: 0.9650 - state_x_loss: 0.1418 - state_y_accuracy: 0.9600 - state_y_loss: 0.1500
# Epoch 188/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3095 - state_x_accuracy: 0.9663 - state_x_loss: 0.1551 - state_y_accuracy: 0.9638 - state_y_loss: 0.1544
# Epoch 189/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3271 - state_x_accuracy: 0.9525 - state_x_loss: 0.1761 - state_y_accuracy: 0.9600 - state_y_loss: 0.1511
# Epoch 190/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2671 - state_x_accuracy: 0.9675 - state_x_loss: 0.1269 - state_y_accuracy: 0.9712 - state_y_loss: 0.1402
# Epoch 191/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2845 - state_x_accuracy: 0.9638 - state_x_loss: 0.1512 - state_y_accuracy: 0.9712 - state_y_loss: 0.1333
# Epoch 192/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2561 - state_x_accuracy: 0.9737 - state_x_loss: 0.1316 - state_y_accuracy: 0.9800 - state_y_loss: 0.1245
# Epoch 193/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2585 - state_x_accuracy: 0.9725 - state_x_loss: 0.1298 - state_y_accuracy: 0.9775 - state_y_loss: 0.1287
# Epoch 194/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2896 - state_x_accuracy: 0.9663 - state_x_loss: 0.1571 - state_y_accuracy: 0.9712 - state_y_loss: 0.1324
# Epoch 195/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2709 - state_x_accuracy: 0.9675 - state_x_loss: 0.1283 - state_y_accuracy: 0.9725 - state_y_loss: 0.1425
# Epoch 196/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2534 - state_x_accuracy: 0.9650 - state_x_loss: 0.1375 - state_y_accuracy: 0.9762 - state_y_loss: 0.1158
# Epoch 197/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2635 - state_x_accuracy: 0.9725 - state_x_loss: 0.1288 - state_y_accuracy: 0.9750 - state_y_loss: 0.1347
# Epoch 198/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2814 - state_x_accuracy: 0.9613 - state_x_loss: 0.1405 - state_y_accuracy: 0.9725 - state_y_loss: 0.1409
# Epoch 199/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2714 - state_x_accuracy: 0.9700 - state_x_loss: 0.1304 - state_y_accuracy: 0.9638 - state_y_loss: 0.1410
# Epoch 200/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2564 - state_x_accuracy: 0.9650 - state_x_loss: 0.1272 - state_y_accuracy: 0.9700 - state_y_loss: 0.1293

# %%
plt.plot(nextstate10, 'b', label = 'Next State Prediction 10x10')
plt.plot(nextstate20, 'r', label = 'Next State Prediction 20x20')
plt.xticks([i*50 for i in range(9)])
plt.grid()
plt.xlabel('Number of Epochs')
plt.ylabel('Accuracy')
plt.legend()

# %% [markdown]
# # Create Grid Environment

# %%
num_actions = 4

class GridEnv(gym.Env):
    """Custom Environment that follows gym interface."""

    metadata = {"render.modes": ["human"]}

    def __init__(self, size=5, start_state = None, goal_state = None, forbidden_squares = [], seed = None):
        super().__init__()

        # initialize action and observation space
        self.action_space = spaces.Discrete(4)
        self.observation_space = spaces.Box(low=0, high=size-1, shape=(4,), dtype=np.uint8)

        self.env_size = size
        self.forbidden_squares = forbidden_squares

        self.steps = 0

        if seed is not None:
          np.random.seed(seed)

        self.start_state = (np.random.randint(0, self.env_size), np.random.randint(0, self.env_size))
        self.goal_state = (np.random.randint(0, self.env_size), np.random.randint(0, self.env_size))

        # make sure we don't spawn in the forbidden squares
        while self.start_state in self.forbidden_squares:
          self.start_state = (np.random.randint(0, self.env_size), np.random.randint(0, self.env_size))
        # make sure we don't spawn in forbidden squares, and that the goal state is not the start state
        while self.goal_state in self.forbidden_squares or self.goal_state == self.start_state:
          self.goal_state = (np.random.randint(0, self.env_size), np.random.randint(0, self.env_size))
        if start_state is not None:
          self.start_state = start_state
        if goal_state is not None:
          self.goal_state = goal_state
        self.cur_state = self.start_state
        self.min_steps = self.get_min()

    def get_min(self):
        ''' Gets the minimum number of moves from start state to goal state using breadth first search '''
        visited = [self.start_state]
        cur_nodes = [self.start_state]
        count = 0
        while self.goal_state not in cur_nodes and count <= self.env_size * self.env_size:
          future_nodes = []
          count += 1 # increment 1 to the visited counts
          while len(cur_nodes) > 0:
            node = cur_nodes.pop()
            for future_node in [(node[0]-1, node[1]), (node[0]+1, node[1]), (node[0], node[1]-1), (node[0], node[1]+1)]:
              if future_node not in visited and 0 <= future_node[0] < self.env_size and 0 <= future_node[1] < self.env_size:
                visited.append(future_node)
                future_nodes.append(future_node)
          cur_nodes = future_nodes.copy()
        return count

    def step(self, action):
        # only step if episode is not terminated
        ''' Takes an action and also returns 1 if the goal state is reached '''
        initial_state = self.cur_state
        # left
        if action == 0 and self.cur_state[0] > 0:
          self.cur_state = (self.cur_state[0]-1, self.cur_state[1])
        # up
        elif action == 1 and self.cur_state[1] > 0:
          self.cur_state = (self.cur_state[0], self.cur_state[1]-1)
        # right
        elif action == 2 and self.cur_state[0]+1 < self.env_size:
          self.cur_state = (self.cur_state[0]+1, self.cur_state[1])
        # down
        elif action == 3 and self.cur_state[1]+1 < self.env_size:
          self.cur_state = (self.cur_state[0], self.cur_state[1]+1)
        # otherwise don't move
        # check if we hit the forbidden states. If so, reposition back to the beginning
        if self.cur_state in self.forbidden_squares:
          self.cur_state = initial_state

        # increment number of steps by 1
        observation = self.cur_state + self.goal_state
        self.steps += 1
        terminated = self.steps >= self.env_size * self.env_size # only stop once we reached end of the training steps

        reward = 0
        # terminate if we have reached the goal
        if self.cur_state == self.goal_state:
          reward = 1
          terminated = True

        return observation, reward, terminated, False, {}

    def reset(self, seed=None, options=None):
        super().reset(seed=seed)
        self.cur_state = self.start_state # reset start state
        observation = self.cur_state + self.goal_state
        self.steps = 0 # reset step count
        return observation, {}  # gymnasium API

    def render(self, mode="human"):
        print(self.cur_state+self.goal_state)

    def close(self):
        ''' Don't have to close anything as we are not rendering anything '''
        return

# %% [markdown]
# ## Helper Functions

# %%
def minion():
    ''' This references existing memory and tries to find a trajectory towards the goal state '''
    # this stores the list of states the minion experiences
    minion_state_history = [cur_state]
    minion_action_history = []
    for depth in range(lookahead_depth):
      # look for matches
      matches = []

      for action in range(num_actions):
        matches.extend([(state, action) for state in memory[minion_state_history[-1]][action]])

      # no match, then discontinue this minion's search
      if len(matches) == 0:
        break

      next_minion_state, next_minion_action = matches[np.random.randint(len(matches))]
      # update minion's value
      minion_state_history.append(next_minion_state)
      if depth==0:
        best_action = next_minion_action
      minion_action_history.append(next_minion_action)

      # check if goal state reached
      if minion_state_history[-1] == goal_state:
        sem.acquire()
        best_minions.put((depth, best_action, minion_state_history[:-1], minion_action_history, next_minion_action))
        sem.release()
        break

def GetModel(seed = 0):
    ''' This takes in a random seed and builds the desired TensorFlow model '''

    # set random seeds
    tf.random.set_seed(seed)
    np.random.seed(seed)

    inputs = tf.keras.layers.Input(shape = (4,))
    # x = tf.keras.layers.Conv2D(filters=16, kernel_size=(3,3), strides=(1,1), padding='same', activation = tf.nn.relu)(inputs)
    # x = tf.keras.layers.MaxPooling2D(pool_size = (2,2))(x)
    # x = tf.keras.layers.Flatten()(x)
    x = tf.keras.layers.Dense(128, activation = tf.nn.relu)(inputs)
    x = tf.keras.layers.Dense(128, activation = tf.nn.relu)(x)
    output1 = tf.keras.layers.Dense(num_actions, activation = tf.nn.softmax)(x)

    model = tf.keras.Model(inputs = inputs, outputs = output1)

    model.compile(optimizer = 'adam',
                  loss = 'sparse_categorical_crossentropy', metrics = ['accuracy'])

    return model

def GetGrid(episode, grid_size = 10):
  ''' This takes in an episode number and returns the desired forbidden squares'''
  # Define what is traversible
  if episode < 50:
    forbidden_squares = [(x, grid_size//2) for x in range(grid_size) if x!=grid_size//2]
  else:
    forbidden_squares = [(grid_size//2, x) for x in range(grid_size) if x!=grid_size//2]

  return forbidden_squares

# %% [markdown]
# # Experiment 1: Solving the grid with fixed start and end points
#
# - We define a 10x10 grid and the agent is supposed to go from (0, 0) to (grid_size-1, grid_size - 1)
# - No obstacles

# %% [markdown]
# ## Model 1: PPO, TRPO, A2C

# %%
for ALGO in [PPO, TRPO, A2C]:
    print (ALGO.__name__)
    grid_size = 10
    # Custom MLP policy of two layers of size 128 each with Relu activation function
    policy_kwargs = dict(activation_fn=torch.nn.ReLU, net_arch=[128, 128])
    # Create the environment
    env = GridEnv(size = grid_size, start_state = (0, 0), goal_state = (grid_size-1, grid_size-1), forbidden_squares = [])
    # Create the agent
    # set random seed
    sb3.common.utils.set_random_seed(0)
    if ALGO == A2C:
      model = ALGO("MlpPolicy", env, policy_kwargs=policy_kwargs, learning_rate = 0.0001)
    else:
      model = ALGO("MlpPolicy", env, policy_kwargs=policy_kwargs)
    model.save("my_env")

    best_steps = []
    actual_steps = []
    for i in range(100):
      # learn for each episode
      env = GridEnv(size = grid_size, start_state = (0, 0), goal_state = (grid_size-1, grid_size-1), forbidden_squares = [])
      model = ALGO.load("my_env", env=env)
      model.learn(total_timesteps=100)
      model.save("my_env")
      obs, _ = env.reset()
      for steps in range(100):
        action, _states = model.predict(obs)
        obs, rewards, terminated, truncated, info = env.step(action)
        done = terminated or truncated
        if done:
          if rewards == 1 and steps+1 < grid_size*grid_size:
            print(f'Run {i+1} completed in {steps+1} steps. Minimum steps: {env.min_steps}, Start state: {env.start_state}, Goal state: {env.goal_state}')

          else:
            print(f'Run {i+1} not completed. Minimum steps: {env.min_steps}, Start state: {env.start_state}, Goal state: {env.goal_state}')
          best_steps.append(env.min_steps)
          actual_steps.append(steps+1)
          break

    # save the best steps
    if ALGO == PPO:
      ppo_steps = actual_steps
    elif ALGO == TRPO:
      trpo_steps = actual_steps
    else:
      a2c_steps = actual_steps
# Out:
# PPO
# Run 1 not completed. Minimum steps: 18, Start state: (0, 0), Goal state: (9, 9)
# Run 2 not completed. Minimum steps: 18, Start state: (0, 0), Goal state: (9, 9)
# Run 3 completed in 47 steps. Minimum steps: 18, Start state: (0, 0), Goal state: (9, 9)
# Run 4 completed in 42 steps. Minimum steps: 18, Start state: (0, 0), Goal state: (9, 9)
# Run 5 completed in 27 steps. Minimum steps: 18, Start state: (0, 0), Goal state: (9, 9)
# Run 6 completed in 27 steps. Minimum steps: 18, Start state: (0, 0), Goal state: (9, 9)
# Run 7 completed in 19 steps. Minimum steps: 18, Start state: (0, 0), Goal state: (9, 9)
# Run 8 completed in 20 steps. Minimum steps: 18, Start state: (0, 0), Goal state: (9, 9)
# Run 9 completed in 20 steps. Minimum steps: 18, Start state: (0, 0), Goal state: (9, 9)
# Run 10 completed in 20 steps. Minimum steps: 18, Start state: (0, 0), Goal state: (9, 9)
# Run 11 completed in 19 steps. Minimum steps: 18, Start state: (0, 0), Goal state: (9, 9)
# Run 12 completed in 18 steps. Minimum steps: 18, Start state: (0, 0), Goal state: (9, 9)
# Run 13 completed in 18 steps. Minimum steps: 18, Start state: (0, 0), Goal state: (9, 9)
# Run 14 completed in 18 steps. Minimum steps: 18, Start state: (0, 0), Goal state: (9, 9)
# Run 15 completed in 18 steps. Minimum steps: 18, Start state: (0, 0), Goal state: (9, 9)
# Run 16 completed in 18 steps. Minimum steps: 18, Start state: (0, 0), Goal state: (9, 9)
# Run 17 completed in 18 steps. Minimum steps: 18, Start state: (0, 0), Goal state: (9, 9)
# Run 18 completed in 18 steps. Minimum steps: 18, Start state: (0, 0), Goal state: (9, 9)
# Run 19 completed in 18 steps. Minimum steps: 18, Start state: (0, 0), Goal state: (9, 9)
# Run 20 completed in 18 steps. Minimum steps: 18, Start state: (0, 0), Goal state: (9, 9)
# Run 21 completed in 18 steps. Minimum steps: 18, Start state: (0, 0), Goal state: (9, 9)
# Run 22 completed in 18 steps. Minimum steps: 18, Start state: (0, 0), Goal state: (9, 9)
# Run 23 completed in 18 steps. Minimum steps: 18, Start state: (0, 0), Goal state: (9, 9)
# Run 24 completed in 18 steps. Minimum steps: 18, Start state: (0, 0), Goal state: (9, 9)
# Run 25 completed in 18 steps. Minimum steps: 18, Start state: (0, 0), Goal state: (9, 9)
# Run 26 completed in 18 steps. Minimum steps: 18, Start state: (0, 0), Goal state: (9, 9)
# Run 27 completed in 18 steps. Minimum steps: 18, Start state: (0, 0), Goal state: (9, 9)
# Run 28 completed in 19 steps. Minimum steps: 18, Start state: (0, 0), Goal state: (9, 9)
# Run 29 completed in 18 steps. Minimum steps: 18, Start state: (0, 0), Goal state: (9, 9)
# Run 30 completed in 18 steps. Minimum steps: 18, Start state: (0, 0), Goal state: (9, 9)
# Run 31 completed in 18 steps. Minimum steps: 18, Start state: (0, 0), Goal state: (9, 9)
# Run 32 completed in 18 steps. Minimum steps: 18, Start state: (0, 0), Goal state: (9, 9)

# %% [markdown]
# ## Model 2: Q-Learning Approach to solving the grid with fixed start and end points
# $Q(s,a) = Q(s,a) + \alpha(r + \gamma\max_a Q(s',a) - Q(s,a))$
#
# The maximum next state value only applies if it is not a terminal state.
#
# Epsilon-greedy action selection, with greedy action being $argmax_a Q(s,a)$

# %%
grid_size = 10
alpha = 1
gamma = 0.99
eps = 1
num_actions = 4
num_episodes = 100

best_steps = []
actual_steps = []
q_values = defaultdict(lambda: 0)
np.random.seed(0)
for i in range(num_episodes):
  env = GridEnv(grid_size, start_state = (0, 0), goal_state = (grid_size-1, grid_size-1), forbidden_squares = [])
  for steps in range(grid_size * grid_size):
    cur_state = env.cur_state
    action = 0
    # take random action if less than desired episode count
    if i<75:
      action = np.random.randint(num_actions)
    # otherwise choose the maximum action
    else:
      action_values = [q_values[(cur_state, a)] for a in range(num_actions)]
      action = np.argmax(action_values)

    obs, rewards, terminated, truncated, _ = env.step(action)
    done = terminated or truncated
    next_state = (obs[0], obs[1])

    # update the Q value tables
    future_action_values = [q_values[(next_state, a)] for a in range(num_actions)]
    old_state_value = q_values[(cur_state, action)]
    if rewards == 1:
      q_values[(cur_state, action)] = old_state_value + alpha*(rewards - old_state_value)
    else:
      q_values[(cur_state, action)] = old_state_value + alpha*(rewards + gamma*np.max(future_action_values) - old_state_value)

    if done:
      if rewards == 1 and steps+1 < grid_size*grid_size:
        print(f'Run {i+1} completed in {steps+1} steps. Minimum steps: {env.min_steps}, Start state: {env.start_state}, Goal state: {env.goal_state}')

      else:
        print(f'Run {i+1} not completed. Minimum steps: {env.min_steps}, Start state: {env.start_state}, Goal state: {env.goal_state}')
      best_steps.append(env.min_steps)
      actual_steps.append(steps+1)
      break

qlearning_steps = actual_steps

# %% [markdown]
# ## Model 3: Memory-based approach

# %%
# hyperparameters
use_fast = True
use_slow = True

grid_size = 10
exploration_const = 1
parallel_threads = 100
lookahead_depth = 20

# create model
model = GetModel()

# reset memory
memory = defaultdict(lambda: defaultdict(lambda: []))

# store only first action
best_steps = []
actual_steps = []

for i in range(100):
  env = GridEnv(grid_size, start_state = (0, 0), goal_state = (grid_size-1, grid_size-1), forbidden_squares = [])
  statehistory = []
  actionhistory = []
  episode_memory = defaultdict(lambda: defaultdict(lambda: []))

  for steps in range(grid_size*grid_size):
    cur_state = env.cur_state
    goal_state = env.goal_state

    # initialize training array
    start_states = []
    start_action = []
    # STEP 1: Fast neural network to get general cue for direction
    if use_fast:
      action_prob = model.predict(np.array(cur_state+goal_state).reshape(-1,4), verbose = 0)
      action_probs = action_prob[0]
    else:
      # set to 0s if not using the fast neural network
      action_probs = np.array([0 for _ in range(num_actions)], dtype = 'float')

    # STEP 2: Do explore-exploit to choose action

    # calculate the exploration parameter, take action_probs and add in count values from instances in memory
    action_probs -= [exploration_const*np.sqrt(len(episode_memory[env.cur_state][i])) for i in range(num_actions)]

    # choose the best action via explore-exploit tradeoff
    action = np.argmax(action_probs)

    # STEP 3: Forward Replay: find out if there is a path in memory to the goal (akin to Model-Based Planning)
    if use_slow:
      best_minions = PriorityQueue()
      best_action = 0

      threads = []
      sem = threading.Semaphore()
      for _ in range(parallel_threads):
        t = Thread(target=minion())
        threads.append(t)
        t.start()

      for t in threads:
        t.join()

      # Do memory action if found in memory. Also, do a replay to learn the transition of the start state to the end state
      if not best_minions.empty():
        depth, action, minion_state_history, minion_action_history, final_action = best_minions.get()
        # print(f'Found best action {action}. Depth {depth}. Current state {env.cur_state}.')

        if depth > 0:
          # update fast neural network with each state on future state trajectory as start state, and the final goal state as the goal state, with each action on future action trajectory
          start_states.extend([x+goal_state for x in minion_state_history])
          start_action.extend([int(x) for x in minion_action_history])

    # perform action
    obs, rewards, terminated, truncated, _ = env.step(action)
    done = terminated or truncated
    next_state = (obs[0], obs[1])

    # STEP 4: store transition in memory, delete irrelevant states if environment has changed
    for mem in [memory, episode_memory]:
      if len(mem[cur_state][action]) > 0 and mem[cur_state][action][-1] != next_state:
        mem[cur_state][action] = [next_state]
      else:
        mem[cur_state][action].append(next_state)

    # append current state and action to history
    statehistory.append(cur_state)
    actionhistory.append(action)

    # terminate if completed
    if done:
      if rewards == 1 and steps+1 < grid_size*grid_size:
        print(f'Run {i+1} completed in {steps+1} steps. Minimum steps: {env.min_steps}, Start state: {env.start_state}, Goal state: {env.goal_state}')

      else:
        print(f'Run {i+1} not completed. Minimum steps: {env.min_steps}, Start state: {env.start_state}, Goal state: {env.goal_state}')
      best_steps.append(env.min_steps)
      actual_steps.append(steps+1)

      break

    # STEP 5: Backward Replay: update fast neural network with next state as goal state, and states before as start state, with current action
    if use_fast:
      start_states.extend([x+next_state for x in statehistory])
      start_action.extend([int(x) for x in actionhistory])
      model.fit(start_states, start_action, epochs=1, verbose = False)

memory_steps = actual_steps

# %%
# Across all states
plt.plot(memory_steps, 'b-', label = 'Fast & Slow')
plt.plot(ppo_steps, 'r-', label = 'PPO')
plt.plot(trpo_steps, 'y-', label = 'TRPO')
plt.plot(a2c_steps, 'g-', label = 'A2C')
plt.plot(qlearning_steps, 'c-', label = 'Q-Learning')
# plt.plot(best_steps, 'm--', label = 'Best')
plt.xlabel('Episode Number')
plt.ylabel('Number of Steps')
plt.legend(loc = 'upper right')
plt.show()

# %%
# Only first 10 states
plt.plot(memory_steps[:10], 'b-', label = 'Fast & Slow')
plt.plot(ppo_steps[:10], 'r-', label = 'PPO')
plt.plot(trpo_steps[:10], 'y-', label = 'TRPO')
plt.plot(a2c_steps[:10], 'g-', label = 'A2C')
plt.plot(qlearning_steps[:10], 'c-', label = 'Q-Learning')
# plt.plot(best_steps[:10], 'm--', label = 'Best')
plt.xlabel('Episode Number')
plt.ylabel('Number of Steps')
plt.legend(loc = 'upper right')
plt.show()

# %%
# This shows us the solve rate and steps above minimum for all methods
for steps in [memory_steps, ppo_steps, trpo_steps, a2c_steps, qlearning_steps]:
  actual_steps = np.array(steps)
  print(f'Number of episodes solved overall is {sum(actual_steps<grid_size*grid_size)}')
  print(f'Number of steps above minimum overall is {sum(actual_steps)-sum(best_steps)}')

# %% [markdown]
# # Experiment 2: Solving the grid with random start and end points
# - Start and end goal differs each episode
# - Obstacles will change every 50 episodes
# - Agent has no pre-built model of the environment and has to lookahead without any external help
# - Agent can rely on stored memory from start of the episodes, and memory can also carry over between episodes

# %% [markdown]
# ## Model 1: PPO, TRPO, A2C

# %%
for ALGO in [PPO, TRPO, A2C]:
    print (ALGO.__name__)
    grid_size = 40
    # Custom MLP policy of two layers of size 128 each with Relu activation function
    policy_kwargs = dict(activation_fn=torch.nn.ReLU, net_arch=[128, 128])
    # Create the environment
    i = 0
    env = GridEnv(grid_size, start_state = None, goal_state = None, forbidden_squares = GetGrid(i, grid_size), seed = i)
    # Create the agent
    # set random seed
    sb3.common.utils.set_random_seed(0)
    if ALGO == A2C:
      model = ALGO("MlpPolicy", env, policy_kwargs=policy_kwargs, learning_rate = 0.0001)
    else:
      model = ALGO("MlpPolicy", env, policy_kwargs=policy_kwargs)
    model.save("my_env")

    best_steps = []
    actual_steps = []
    for i in range(100):
      # learn for each episode
      env = GridEnv(grid_size, start_state = None, goal_state = None, forbidden_squares = GetGrid(i, grid_size), seed = i)
      model = ALGO.load("my_env", env=env)
      model.learn(total_timesteps=100)
      model.save("my_env")
      obs, _ = env.reset()
      for steps in range(grid_size*grid_size):
        action, _states = model.predict(obs)
        obs, rewards, terminated, truncated, info = env.step(action)
        done = terminated or truncated
        if done:
          if rewards == 1 and steps+1 < grid_size*grid_size:
            print(f'Run {i+1} completed in {steps+1} steps. Minimum steps: {env.min_steps}, Start state: {env.start_state}, Goal state: {env.goal_state}')

          else:
            print(f'Run {i+1} not completed. Minimum steps: {env.min_steps}, Start state: {env.start_state}, Goal state: {env.goal_state}')
          best_steps.append(env.min_steps)
          actual_steps.append(steps+1)

          break

    plt.plot(best_steps, 'b-', label = 'Minimum Steps per Episode')
    plt.plot(actual_steps, 'g-', label = 'Actual Steps per Episode')
    plt.xlabel('Episode number')
    plt.ylabel('Number of Steps')
    plt.xticks([i*10 for i in range(11)])
    # plt.legend(loc = 'upper right')
    plt.show()

    actual_steps = np.array(actual_steps)
    print(f'Number of steps above minimum for first 50 epochs is {sum(actual_steps[:50])-sum(best_steps[:50])}')
    print(f'Number of steps above minimum for last 50 epochs is {sum(actual_steps[50:])-sum(best_steps[50:])}')
    print(f'Number of steps above minimum overall is {sum(actual_steps)-sum(best_steps)}')
    print(f'Number of episodes solved for first 50 epochs is {sum(actual_steps[:50]<grid_size*grid_size)}')
    print(f'Number of episodes solved for last 50 epochs is {sum(actual_steps[50:]<grid_size*grid_size)}')
    print(f'Number of episodes solved overall is {sum(actual_steps<grid_size*grid_size)}')

    # save the best steps
    if ALGO == PPO:
      ppo_best_steps = best_steps
    elif ALGO == TRPO:
      trpo_steps = best_steps
    else:
      a2c_steps = best_steps

# %% [markdown]
# ## Model 2: Fast and Slow

# %%
# hyperparameters
use_fast = True
use_slow = True

grid_size = 10
exploration_const = 1
parallel_threads = 100
lookahead_depth = 20

# create model
model = GetModel()

# reset memory
memory = defaultdict(lambda: defaultdict(lambda: []))

# store only first action
best_steps = []
actual_steps = []

for i in range(100):
  env = GridEnv(grid_size, start_state = None, goal_state = None, forbidden_squares = GetGrid(i, grid_size), seed = i)
  statehistory = []
  actionhistory = []
  episode_memory = defaultdict(lambda: defaultdict(lambda: []))

  for steps in range(grid_size*grid_size):
    cur_state = env.cur_state
    goal_state = env.goal_state

    # initialize training array
    start_states = []
    start_action = []
    # STEP 1: Fast neural network to get general cue for direction
    if use_fast:
      action_prob = model.predict(np.array(cur_state+goal_state).reshape(-1,4), verbose = 0)
      action_probs = action_prob[0]
    else:
      # set to 0s if not using the fast neural network
      action_probs = np.array([0 for _ in range(num_actions)], dtype = 'float')

    # STEP 2: Do explore-exploit to choose action

    # calculate the exploration parameter, take action_probs and add in count values from instances in memory
    action_probs -= [exploration_const*np.sqrt(len(episode_memory[env.cur_state][i])) for i in range(num_actions)]

    # choose the best action via explore-exploit tradeoff
    action = np.argmax(action_probs)

    # STEP 3: Forward Replay: find out if there is a path in memory to the goal (akin to Model-Based Planning)
    if use_slow:
      best_minions = PriorityQueue()
      best_action = 0

      threads = []
      sem = threading.Semaphore()
      for _ in range(parallel_threads):
        t = Thread(target=minion())
        threads.append(t)
        t.start()

      for t in threads:
        t.join()

      # Do memory action if found in memory. Also, do a replay to learn the transition of the start state to the end state
      if not best_minions.empty():
        depth, action, minion_state_history, minion_action_history, final_action = best_minions.get()
        # print(f'Found best action {action}. Depth {depth}. Current state {env.cur_state}.')

        if depth > 0:
          # update fast neural network with each state on future state trajectory as start state, and the final goal state as the goal state, with each action on future action trajectory
          start_states.extend([x+goal_state for x in minion_state_history])
          start_action.extend([int(x) for x in minion_action_history])

    # perform action
    obs, rewards, terminated, truncated, _ = env.step(action)
    done = terminated or truncated
    next_state = (obs[0], obs[1])

    # STEP 4: store transition in memory, delete irrelevant states if environment has changed
    for mem in [memory, episode_memory]:
      if len(mem[cur_state][action]) > 0 and mem[cur_state][action][-1] != next_state:
        mem[cur_state][action] = [next_state]
      else:
        mem[cur_state][action].append(next_state)

    # append current state and action to history
    statehistory.append(cur_state)
    actionhistory.append(action)

    # terminate if completed
    if done:
      if rewards == 1 and steps+1 < grid_size*grid_size:
        print(f'Run {i+1} completed in {steps+1} steps. Minimum steps: {env.min_steps}, Start state: {env.start_state}, Goal state: {env.goal_state}')

      else:
        print(f'Run {i+1} not completed. Minimum steps: {env.min_steps}, Start state: {env.start_state}, Goal state: {env.goal_state}')
      best_steps.append(env.min_steps)
      actual_steps.append(steps+1)

      break

    # STEP 5: Backward Replay: update fast neural network with next state as goal state, and states before as start state, with current action
    if use_fast:
      start_states.extend([x+next_state for x in statehistory])
      start_action.extend([int(x) for x in actionhistory])
      model.fit(start_states, start_action, epochs=1, verbose = False)

# %%
plt.plot(best_steps, 'b-', label = 'Minimum Steps per Episode')
plt.plot(actual_steps, 'g-', label = 'Actual Steps per Episode')
plt.xlabel('Episode number')
plt.ylabel('Number of Steps')
plt.xticks([i*10 for i in range(11)])
# plt.legend(loc = 'upper right')
plt.show()

actual_steps = np.array(actual_steps)
print(f'Number of steps above minimum for first 50 epochs is {sum(actual_steps[:50])-sum(best_steps[:50])}')
print(f'Number of steps above minimum for last 50 epochs is {sum(actual_steps[50:])-sum(best_steps[50:])}')
print(f'Number of steps above minimum overall is {sum(actual_steps)-sum(best_steps)}')
print(f'Number of episodes solved for first 50 epochs is {sum(actual_steps[:50]<grid_size*grid_size)}')
print(f'Number of episodes solved for last 50 epochs is {sum(actual_steps[50:]<grid_size*grid_size)}')
print(f'Number of episodes solved overall is {sum(actual_steps<grid_size*grid_size)}')

# %% [markdown]
# ## Model 3: Without slow memory mechanism

# %%
# hyperparameters
use_fast = True
use_slow = False

grid_size = 10
exploration_const = 1
parallel_threads = 100
lookahead_depth = 20

# create model
model = GetModel()

# reset memory
memory = defaultdict(lambda: defaultdict(lambda: []))

# store only first action
best_steps = []
actual_steps = []

for i in range(100):
  env = GridEnv(grid_size, start_state = None, goal_state = None, forbidden_squares = GetGrid(i, grid_size), seed = i)
  statehistory = []
  actionhistory = []
  episode_memory = defaultdict(lambda: defaultdict(lambda: []))

  for steps in range(grid_size*grid_size):
    cur_state = env.cur_state
    goal_state = env.goal_state

    # initialize training array
    start_states = []
    start_action = []
    # STEP 1: Fast neural network to get general cue for direction
    if use_fast:
      action_prob = model.predict(np.array(cur_state+goal_state).reshape(-1,4), verbose = 0)
      action_probs = action_prob[0]
    else:
      # set to 0s if not using the fast neural network
      action_probs = np.array([0 for _ in range(num_actions)], dtype = 'float')

    # STEP 2: Do explore-exploit to choose action

    # calculate the exploration parameter, take action_probs and add in count values from instances in memory
    action_probs -= [exploration_const*np.sqrt(len(episode_memory[env.cur_state][i])) for i in range(num_actions)]

    # choose the best action via explore-exploit tradeoff
    action = np.argmax(action_probs)

    # STEP 3: Forward Replay: find out if there is a path in memory to the goal (akin to Model-Based Planning)
    if use_slow:
      best_minions = PriorityQueue()
      best_action = 0

      threads = []
      sem = threading.Semaphore()
      for _ in range(parallel_threads):
        t = Thread(target=minion())
        threads.append(t)
        t.start()

      for t in threads:
        t.join()

      # Do memory action if found in memory. Also, do a replay to learn the transition of the start state to the end state
      if not best_minions.empty():
        depth, action, minion_state_history, minion_action_history, final_action = best_minions.get()
        # print(f'Found best action {action}. Depth {depth}. Current state {env.cur_state}.')

        if depth > 0:
          # update fast neural network with each state on future state trajectory as start state, and the final goal state as the goal state, with each action on future action trajectory
          start_states.extend([x+goal_state for x in minion_state_history])
          start_action.extend([int(x) for x in minion_action_history])

    # perform action
    obs, rewards, terminated, truncated, _ = env.step(action)
    done = terminated or truncated
    next_state = (obs[0], obs[1])

    # STEP 4: store transition in memory, delete irrelevant states if environment has changed
    for mem in [memory, episode_memory]:
      if len(mem[cur_state][action]) > 0 and mem[cur_state][action][-1] != next_state:
        mem[cur_state][action] = [next_state]
      else:
        mem[cur_state][action].append(next_state)

    # append current state and action to history
    statehistory.append(cur_state)
    actionhistory.append(action)

    # terminate if completed
    if done:
      if rewards == 1 and steps+1 < grid_size*grid_size:
        print(f'Run {i+1} completed in {steps+1} steps. Minimum steps: {env.min_steps}, Start state: {env.start_state}, Goal state: {env.goal_state}')

      else:
        print(f'Run {i+1} not completed. Minimum steps: {env.min_steps}, Start state: {env.start_state}, Goal state: {env.goal_state}')
      best_steps.append(env.min_steps)
      actual_steps.append(steps+1)

      break

    # STEP 5: Backward Replay: update fast neural network with next state as goal state, and states before as start state, with current action
    if use_fast:
      start_states.extend([x+next_state for x in statehistory])
      start_action.extend([int(x) for x in actionhistory])
      model.fit(start_states, start_action, epochs=1, verbose = False)

# %%
plt.plot(best_steps, 'b-', label = 'Minimum Steps per Episode')
plt.plot(actual_steps, 'g-', label = 'Actual Steps per Episode')
plt.xlabel('Episode number')
plt.ylabel('Number of Steps')
plt.xticks([i*10 for i in range(11)])
# plt.legend(loc = 'upper right')
plt.show()

actual_steps = np.array(actual_steps)
print(f'Number of steps above minimum for first 50 epochs is {sum(actual_steps[:50])-sum(best_steps[:50])}')
print(f'Number of steps above minimum for last 50 epochs is {sum(actual_steps[50:])-sum(best_steps[50:])}')
print(f'Number of steps above minimum overall is {sum(actual_steps)-sum(best_steps)}')
print(f'Number of episodes solved for first 50 epochs is {sum(actual_steps[:50]<grid_size*grid_size)}')
print(f'Number of episodes solved for last 50 epochs is {sum(actual_steps[50:]<grid_size*grid_size)}')
print(f'Number of episodes solved overall is {sum(actual_steps<grid_size*grid_size)}')

# %% [markdown]
# ## Model 4: Without fast goal-directed mechanism

# %%
# hyperparameters
use_fast = False
use_slow = True

grid_size = 10
exploration_const = 1
parallel_threads = 100
lookahead_depth = 20

# create model
model = GetModel()

# reset memory
memory = defaultdict(lambda: defaultdict(lambda: []))

# store only first action
best_steps = []
actual_steps = []

for i in range(100):
  env = GridEnv(grid_size, start_state = None, goal_state = None, forbidden_squares = GetGrid(i, grid_size), seed = i)
  statehistory = []
  actionhistory = []
  episode_memory = defaultdict(lambda: defaultdict(lambda: []))

  for steps in range(grid_size*grid_size):
    cur_state = env.cur_state
    goal_state = env.goal_state

    # initialize training array
    start_states = []
    start_action = []
    # STEP 1: Fast neural network to get general cue for direction
    if use_fast:
      action_prob = model.predict(np.array(cur_state+goal_state).reshape(-1,4), verbose = 0)
      action_probs = action_prob[0]
    else:
      # set to 0s if not using the fast neural network
      action_probs = np.array([0 for _ in range(num_actions)], dtype = 'float')

    # STEP 2: Do explore-exploit to choose action

    # calculate the exploration parameter, take action_probs and add in count values from instances in memory
    action_probs -= [exploration_const*np.sqrt(len(episode_memory[env.cur_state][i])) for i in range(num_actions)]

    # choose the best action via explore-exploit tradeoff
    action = np.argmax(action_probs)

    # STEP 3: Forward Replay: find out if there is a path in memory to the goal (akin to Model-Based Planning)
    if use_slow:
      best_minions = PriorityQueue()
      best_action = 0

      threads = []
      sem = threading.Semaphore()
      for _ in range(parallel_threads):
        t = Thread(target=minion())
        threads.append(t)
        t.start()

      for t in threads:
        t.join()

      # Do memory action if found in memory. Also, do a replay to learn the transition of the start state to the end state
      if not best_minions.empty():
        depth, action, minion_state_history, minion_action_history, final_action = best_minions.get()
        # print(f'Found best action {action}. Depth {depth}. Current state {env.cur_state}.')

        if depth > 0:
          # update fast neural network with each state on future state trajectory as start state, and the final goal state as the goal state, with each action on future action trajectory
          start_states.extend([x+goal_state for x in minion_state_history])
          start_action.extend([int(x) for x in minion_action_history])

    # perform action
    obs, rewards, terminated, truncated, _ = env.step(action)
    done = terminated or truncated
    next_state = (obs[0], obs[1])

    # STEP 4: store transition in memory, delete irrelevant states if environment has changed
    for mem in [memory, episode_memory]:
      if len(mem[cur_state][action]) > 0 and mem[cur_state][action][-1] != next_state:
        mem[cur_state][action] = [next_state]
      else:
        mem[cur_state][action].append(next_state)

    # append current state and action to history
    statehistory.append(cur_state)
    actionhistory.append(action)

    # terminate if completed
    if done:
      if rewards == 1 and steps+1 < grid_size*grid_size:
        print(f'Run {i+1} completed in {steps+1} steps. Minimum steps: {env.min_steps}, Start state: {env.start_state}, Goal state: {env.goal_state}')

      else:
        print(f'Run {i+1} not completed. Minimum steps: {env.min_steps}, Start state: {env.start_state}, Goal state: {env.goal_state}')
      best_steps.append(env.min_steps)
      actual_steps.append(steps+1)

      break

    # STEP 5: Backward Replay: update fast neural network with next state as goal state, and states before as start state, with current action
    if use_fast:
      start_states.extend([x+next_state for x in statehistory])
      start_action.extend([int(x) for x in actionhistory])
      model.fit(start_states, start_action, epochs=1, verbose = False)

# %%
plt.plot(best_steps, 'b-', label = 'Minimum Steps per Episode')
plt.plot(actual_steps, 'g-', label = 'Actual Steps per Episode')
plt.xlabel('Episode number')
plt.ylabel('Number of Steps')
plt.xticks([i*10 for i in range(11)])
# plt.legend(loc = 'upper right')
plt.show()

actual_steps = np.array(actual_steps)
print(f'Number of steps above minimum for first 50 epochs is {sum(actual_steps[:50])-sum(best_steps[:50])}')
print(f'Number of steps above minimum for last 50 epochs is {sum(actual_steps[50:])-sum(best_steps[50:])}')
print(f'Number of steps above minimum overall is {sum(actual_steps)-sum(best_steps)}')
print(f'Number of episodes solved for first 50 epochs is {sum(actual_steps[:50]<grid_size*grid_size)}')
print(f'Number of episodes solved for last 50 epochs is {sum(actual_steps[50:]<grid_size*grid_size)}')
print(f'Number of episodes solved overall is {sum(actual_steps<grid_size*grid_size)}')

# %% [markdown]
# ## Model 5: Without slow memory and fast goal-directed mechanism
# Just explore-exploit

# %%
# hyperparameters
use_fast = False
use_slow = False

grid_size = 10
exploration_const = 1
parallel_threads = 100
lookahead_depth = 20

# create model
model = GetModel()

# reset memory
memory = defaultdict(lambda: defaultdict(lambda: []))

# store only first action
best_steps = []
actual_steps = []

for i in range(100):
  env = GridEnv(grid_size, start_state = None, goal_state = None, forbidden_squares = GetGrid(i, grid_size), seed = i)
  statehistory = []
  actionhistory = []
  episode_memory = defaultdict(lambda: defaultdict(lambda: []))

  for steps in range(grid_size*grid_size):
    cur_state = env.cur_state
    goal_state = env.goal_state

    # initialize training array
    start_states = []
    start_action = []
    # STEP 1: Fast neural network to get general cue for direction
    if use_fast:
      action_prob = model.predict(np.array(cur_state+goal_state).reshape(-1,4), verbose = 0)
      action_probs = action_prob[0]
    else:
      # set to 0s if not using the fast neural network
      action_probs = np.array([0 for _ in range(num_actions)], dtype = 'float')

    # STEP 2: Do explore-exploit to choose action

    # calculate the exploration parameter, take action_probs and add in count values from instances in memory
    action_probs -= [exploration_const*np.sqrt(len(episode_memory[env.cur_state][i])) for i in range(num_actions)]

    # choose the best action via explore-exploit tradeoff
    action = np.argmax(action_probs)

    # STEP 3: Forward Replay: find out if there is a path in memory to the goal (akin to Model-Based Planning)
    if use_slow:
      best_minions = PriorityQueue()
      best_action = 0

      threads = []
      sem = threading.Semaphore()
      for _ in range(parallel_threads):
        t = Thread(target=minion())
        threads.append(t)
        t.start()

      for t in threads:
        t.join()

      # Do memory action if found in memory. Also, do a replay to learn the transition of the start state to the end state
      if not best_minions.empty():
        depth, action, minion_state_history, minion_action_history, final_action = best_minions.get()
        # print(f'Found best action {action}. Depth {depth}. Current state {env.cur_state}.')

        if depth > 0:
          # update fast neural network with each state on future state trajectory as start state, and the final goal state as the goal state, with each action on future action trajectory
          start_states.extend([x+goal_state for x in minion_state_history])
          start_action.extend([int(x) for x in minion_action_history])

    # perform action
    obs, rewards, terminated, truncated, _ = env.step(action)
    done = terminated or truncated
    next_state = (obs[0], obs[1])

    # STEP 4: store transition in memory, delete irrelevant states if environment has changed
    for mem in [memory, episode_memory]:
      if len(mem[cur_state][action]) > 0 and mem[cur_state][action][-1] != next_state:
        mem[cur_state][action] = [next_state]
      else:
        mem[cur_state][action].append(next_state)

    # append current state and action to history
    statehistory.append(cur_state)
    actionhistory.append(action)

    # terminate if completed
    if done:
      if rewards == 1:
        print(f'Run {i+1} completed in {steps+1} steps. Minimum steps: {env.min_steps}, Start state: {env.start_state}, Goal state: {env.goal_state}')
        best_steps.append(env.min_steps)
        actual_steps.append(steps+1)

      else:
        print(f'Run {i+1} not completed. Minimum steps: {env.min_steps}, Start state: {env.start_state}, Goal state: {env.goal_state}')
        best_steps.append(env.min_steps)
        actual_steps.append(steps+1)

      break

    # STEP 5: Backward Replay: update fast neural network with next state as goal state, and states before as start state, with current action
    if use_fast:
      start_states.extend([x+next_state for x in statehistory])
      start_action.extend([int(x) for x in actionhistory])
      model.fit(start_states, start_action, epochs=1, verbose = False)

# %%
plt.plot(best_steps, 'b-', label = 'Minimum Steps per Episode')
plt.plot(actual_steps, 'g-', label = 'Actual Steps per Episode')
plt.xlabel('Episode number')
plt.ylabel('Number of Steps')
plt.xticks([i*10 for i in range(11)])
# plt.legend(loc = 'upper right')
plt.show()

actual_steps = np.array(actual_steps)
print(f'Number of steps above minimum for first 50 epochs is {sum(actual_steps[:50])-sum(best_steps[:50])}')
print(f'Number of steps above minimum for last 50 epochs is {sum(actual_steps[50:])-sum(best_steps[50:])}')
print(f'Number of steps above minimum overall is {sum(actual_steps)-sum(best_steps)}')
print(f'Number of episodes solved for first 50 epochs is {sum(actual_steps[:50]<grid_size*grid_size)}')
print(f'Number of episodes solved for last 50 epochs is {sum(actual_steps[50:]<grid_size*grid_size)}')
print(f'Number of episodes solved overall is {sum(actual_steps<grid_size*grid_size)}')

# %% [markdown]
# # Ablation Studies
# - Vary lookahead depth
# - Vary number of parallel branch

# %%
for lookahead_depth in [5, 10, 50]:

    # hyperparameters
    use_fast = True
    use_slow = True

    grid_size = 10
    exploration_const = 1
    parallel_threads = 100
    # lookahead_depth = 20

    # create model
    model = GetModel()

    # reset memory
    memory = defaultdict(lambda: defaultdict(lambda: []))

    # store only first action
    best_steps = []
    actual_steps = []

    for i in range(100):
      env = GridEnv(grid_size, start_state = None, goal_state = None, forbidden_squares = GetGrid(i, grid_size), seed = i)
      statehistory = []
      actionhistory = []
      episode_memory = defaultdict(lambda: defaultdict(lambda: []))

      for steps in range(grid_size*grid_size):
        cur_state = env.cur_state
        goal_state = env.goal_state

        # initialize training array
        start_states = []
        start_action = []
        # STEP 1: Fast neural network to get general cue for direction
        if use_fast:
          action_prob = model.predict(np.array(cur_state+goal_state).reshape(-1,4), verbose = 0)
          action_probs = action_prob[0]
        else:
          # set to 0s if not using the fast neural network
          action_probs = np.array([0 for _ in range(num_actions)], dtype = 'float')

        # STEP 2: Do explore-exploit to choose action

        # calculate the exploration parameter, take action_probs and add in count values from instances in memory
        action_probs -= [exploration_const*np.sqrt(len(episode_memory[env.cur_state][i])) for i in range(num_actions)]

        # choose the best action via explore-exploit tradeoff
        action = np.argmax(action_probs)

        # STEP 3: Forward Replay: find out if there is a path in memory to the goal (akin to Model-Based Planning)
        if use_slow:
          best_minions = PriorityQueue()
          best_action = 0

          threads = []
          sem = threading.Semaphore()
          for _ in range(parallel_threads):
            t = Thread(target=minion())
            threads.append(t)
            t.start()

          for t in threads:
            t.join()

          # Do memory action if found in memory. Also, do a replay to learn the transition of the start state to the end state
          if not best_minions.empty():
            depth, action, minion_state_history, minion_action_history, final_action = best_minions.get()
            # print(f'Found best action {action}. Depth {depth}. Current state {env.cur_state}.')

            if depth > 0:
              # update fast neural network with each state on future state trajectory as start state, and the final goal state as the goal state, with each action on future action trajectory
              start_states.extend([x+goal_state for x in minion_state_history])
              start_action.extend([int(x) for x in minion_action_history])

        # perform action
        obs, rewards, terminated, truncated, _ = env.step(action)
    done = terminated or truncated
        next_state = (obs[0], obs[1])

        # STEP 4: store transition in memory, delete irrelevant states if environment has changed
        for mem in [memory, episode_memory]:
          if len(mem[cur_state][action]) > 0 and mem[cur_state][action][-1] != next_state:
            mem[cur_state][action] = [next_state]
          else:
            mem[cur_state][action].append(next_state)

        # append current state and action to history
        statehistory.append(cur_state)
        actionhistory.append(action)

        # terminate if completed
        if done:
          if rewards == 1:
            print(f'Run {i+1} completed in {steps+1} steps. Minimum steps: {env.min_steps}, Start state: {env.start_state}, Goal state: {env.goal_state}')
            best_steps.append(env.min_steps)
            actual_steps.append(steps+1)

          else:
            print(f'Run {i+1} not completed. Minimum steps: {env.min_steps}, Start state: {env.start_state}, Goal state: {env.goal_state}')
            best_steps.append(env.min_steps)
            actual_steps.append(steps+1)

          break

        # STEP 5: Backward Replay: update fast neural network with next state as goal state, and states before as start state, with current action
        if use_fast:
          start_states.extend([x+next_state for x in statehistory])
          start_action.extend([int(x) for x in actionhistory])
          model.fit(start_states, start_action, epochs=1, verbose = False)

    plt.plot(best_steps, 'b-', label = 'Minimum Steps per Episode')
    plt.plot(actual_steps, 'g-', label = 'Actual Steps per Episode')
    plt.xlabel('Episode number')
    plt.ylabel('Number of Steps')
    plt.xticks([i*10 for i in range(11)])
    # plt.legend(loc = 'upper right')
    plt.show()

    actual_steps = np.array(actual_steps)
    print(f'Number of steps above minimum for first 50 epochs is {sum(actual_steps[:50])-sum(best_steps[:50])}')
    print(f'Number of steps above minimum for last 50 epochs is {sum(actual_steps[50:])-sum(best_steps[50:])}')
    print(f'Number of steps above minimum overall is {sum(actual_steps)-sum(best_steps)}')
    print(f'Number of episodes solved for first 50 epochs is {sum(actual_steps[:50]<grid_size*grid_size)}')
    print(f'Number of episodes solved for last 50 epochs is {sum(actual_steps[50:]<grid_size*grid_size)}')
    print(f'Number of episodes solved overall is {sum(actual_steps<grid_size*grid_size)}')

# %%
for parallel_threads in [10, 50, 200]:

    # hyperparameters
    use_fast = True
    use_slow = True

    grid_size = 10
    exploration_const = 1
    # parallel_threads = 100
    lookahead_depth = 20

    # create model
    model = GetModel()

    # reset memory
    memory = defaultdict(lambda: defaultdict(lambda: []))

    # store only first action
    best_steps = []
    actual_steps = []

    for i in range(100):
      env = GridEnv(grid_size, start_state = None, goal_state = None, forbidden_squares = GetGrid(i, grid_size), seed = i)
      statehistory = []
      actionhistory = []
      episode_memory = defaultdict(lambda: defaultdict(lambda: []))

      for steps in range(grid_size*grid_size):
        cur_state = env.cur_state
        goal_state = env.goal_state

        # initialize training array
        start_states = []
        start_action = []
        # STEP 1: Fast neural network to get general cue for direction
        if use_fast:
          action_prob = model.predict(np.array(cur_state+goal_state).reshape(-1,4), verbose = 0)
          action_probs = action_prob[0]
        else:
          # set to 0s if not using the fast neural network
          action_probs = np.array([0 for _ in range(num_actions)], dtype = 'float')

        # STEP 2: Do explore-exploit to choose action

        # calculate the exploration parameter, take action_probs and add in count values from instances in memory
        action_probs -= [exploration_const*np.sqrt(len(episode_memory[env.cur_state][i])) for i in range(num_actions)]

        # choose the best action via explore-exploit tradeoff
        action = np.argmax(action_probs)

        # STEP 3: Forward Replay: find out if there is a path in memory to the goal (akin to Model-Based Planning)
        if use_slow:
          best_minions = PriorityQueue()
          best_action = 0

          threads = []
          sem = threading.Semaphore()
          for _ in range(parallel_threads):
            t = Thread(target=minion())
            threads.append(t)
            t.start()

          for t in threads:
            t.join()

          # Do memory action if found in memory. Also, do a replay to learn the transition of the start state to the end state
          if not best_minions.empty():
            depth, action, minion_state_history, minion_action_history, final_action = best_minions.get()
            # print(f'Found best action {action}. Depth {depth}. Current state {env.cur_state}.')

            if depth > 0:
              # update fast neural network with each state on future state trajectory as start state, and the final goal state as the goal state, with each action on future action trajectory
              start_states.extend([x+goal_state for x in minion_state_history])
              start_action.extend([int(x) for x in minion_action_history])

        # perform action
        obs, rewards, terminated, truncated, _ = env.step(action)
    done = terminated or truncated
        next_state = (obs[0], obs[1])

        # STEP 4: store transition in memory, delete irrelevant states if environment has changed
        for mem in [memory, episode_memory]:
          if len(mem[cur_state][action]) > 0 and mem[cur_state][action][-1] != next_state:
            mem[cur_state][action] = [next_state]
          else:
            mem[cur_state][action].append(next_state)

        # append current state and action to history
        statehistory.append(cur_state)
        actionhistory.append(action)

        # terminate if completed
        if done:
          if rewards == 1:
            print(f'Run {i+1} completed in {steps+1} steps. Minimum steps: {env.min_steps}, Start state: {env.start_state}, Goal state: {env.goal_state}')
            best_steps.append(env.min_steps)
            actual_steps.append(steps+1)

          else:
            print(f'Run {i+1} not completed. Minimum steps: {env.min_steps}, Start state: {env.start_state}, Goal state: {env.goal_state}')
            best_steps.append(env.min_steps)
            actual_steps.append(steps+1)

          break

        # STEP 5: Backward Replay: update fast neural network with next state as goal state, and states before as start state, with current action
        if use_fast:
          start_states.extend([x+next_state for x in statehistory])
          start_action.extend([int(x) for x in actionhistory])
          model.fit(start_states, start_action, epochs=1, verbose = False)

    plt.plot(best_steps, 'b-', label = 'Minimum Steps per Episode')
    plt.plot(actual_steps, 'g-', label = 'Actual Steps per Episode')
    plt.xlabel('Episode number')
    plt.ylabel('Number of Steps')
    plt.xticks([i*10 for i in range(11)])
    # plt.legend(loc = 'upper right')
    plt.show()

    actual_steps = np.array(actual_steps)
    print(f'Number of steps above minimum for first 50 epochs is {sum(actual_steps[:50])-sum(best_steps[:50])}')
    print(f'Number of steps above minimum for last 50 epochs is {sum(actual_steps[50:])-sum(best_steps[50:])}')
    print(f'Number of steps above minimum overall is {sum(actual_steps)-sum(best_steps)}')
    print(f'Number of episodes solved for first 50 epochs is {sum(actual_steps[:50]<grid_size*grid_size)}')
    print(f'Number of episodes solved for last 50 epochs is {sum(actual_steps[50:]<grid_size*grid_size)}')
    print(f'Number of episodes solved overall is {sum(actual_steps<grid_size*grid_size)}')
